# %% [markdown]
# # [작업 자동 기록 서비스]

# %% [markdown]
# *   기간: 2025-11-13 ~ 2023-11-26 (총 14일)
# *   리더: 이진호
# *
# *   정의:
# *   목적:
# *   범위:

# %% [markdown]
# ## [할 일 목록]

# %% [markdown]
# ### [1일차]

# %% [markdown]
# #### 1.  ****

# %% [markdown]
# 필요할 경우 상세 설명을 기술합니다.

# %% [markdown]
# ### [2일차]

# %% [markdown]
# ### [3일차]

# %% [markdown]
# ### [4일차]

# %% [markdown]
# ### [5일차]

# %% [markdown]
# ## [이슈 항목]

# %% [markdown]
# ### 1.  ~~~~용량이 6G -> 52G로 증가~~~~

# %% [markdown]
# jpg로 압축된 데이터를 TCN에 넣기 위하여 tensor로 변환 하였으나,
#
# Window 15, Step 5 로 인한 용량 증가 3배 *
