# %%
import os
import glob
import cv2
import numpy as np
import matplotlib.pyplot as plt
from natsort import natsorted
from ultralytics import YOLO

# %% [markdown]
# ## 이미지를 영상으로 변환

# %%
def images_to_video(
    img_dir: str,
    out_video_path: str,
    fps: float = 7.5,
    img_exts=(".jpg", ".png")
):
    """
    img_dir 안의 이미지들을 자연 정렬 후 7.5fps 영상으로 저장.
    """
    img_paths = []
    for ext in img_exts:
        img_paths.extend(glob.glob(os.path.join(img_dir, f"*{ext}")))
    img_paths = natsorted(img_paths)

    if not img_paths:
        raise RuntimeError(f"[ERROR] No images found in {img_dir}")

    # 첫 프레임으로 크기 획득
    sample = cv2.imread(img_paths[0])
    if sample is None:
        raise RuntimeError(f"[ERROR] Failed to read first image: {img_paths[0]}")
    h, w = sample.shape[:2]

    fourcc = cv2.VideoWriter_fourcc(*"mp4v")
    writer = cv2.VideoWriter(out_video_path, fourcc, fps, (w, h))

    for p in img_paths:
        frame = cv2.imread(p)
        if frame is None:
            print(f"[WARN] skip invalid image: {p}")
            continue
        writer.write(frame)

    writer.release()
    print(f"[INFO] Video saved: {out_video_path}")

# %%
# YOLO 시각화 이미지를 7.5fps 영상으로 변환
OUT_YOLO_VIDEO = r"demo\origin\video_normal_new_002.mp4"
OUT_OC_FE_DIR1 = r"test_data\test_video\video_normal_new_002(fast)"
images_to_video(OUT_OC_FE_DIR1, OUT_YOLO_VIDEO, fps=7.5)

# YOLO 시각화 이미지를 7.5fps 영상으로 변환
OUT_YOLO_VIDEO = r"demo\origin\video_normal_new_003.mp4"
OUT_OC_FE_DIR2 = r"test_data\test_video\video_normal_new_003"
images_to_video(OUT_OC_FE_DIR2, OUT_YOLO_VIDEO, fps=7.5)

# YOLO 시각화 이미지를 7.5fps 영상으로 변환
OUT_YOLO_VIDEO = r"demo\origin\video_missing1_new_002.mp4"
OUT_OC_FE_DIR3 = r"test_data\test_video\video_missing1_new_002"
images_to_video(OUT_OC_FE_DIR3, OUT_YOLO_VIDEO, fps=7.5)
# Out:
# [INFO] Video saved: demo\origin\video_normal_new_002.mp4
# [INFO] Video saved: demo\origin\video_normal_new_003.mp4
# [INFO] Video saved: demo\origin\video_missing1_new_002.mp4

# %% [markdown]
# ## yolo 시각화

# %%
IMG_DIR1    = r"test_data/test_video/video_normal_new_002(fast)"      # 시각화할 이미지들이 들어있는 폴더
IMG_DIR2    = r"test_data\test_video\video_normal_new_003"
IMG_DIR3    = r"test_data\test_video\video_missing1_new_002"

# %%
# ===== 경로 설정 =====
WEIGHT_OC = r"G:\GitProjects\sessac_project\yolo\best_openclose.pt"   # open/close 모델 가중치 경로
WEIGHT_FE = r"G:\GitProjects\sessac_project\yolo\best_fullempty.pt"   # full/empty 모델 가중치 경로

OUT_OC_FE_DIR = r"demo\yolo"        # 시각화 이미지 저장 폴더
os.makedirs(OUT_OC_FE_DIR, exist_ok=True)

# ===== 모델 로드 =====
model_oc = YOLO(WEIGHT_OC)
model_fe = YOLO(WEIGHT_FE)

# %%
# ===== 샘플 이미지 목록 =====
sample_imgs = []
for ext in ("*.jpg", "*.png"):
    sample_imgs.extend(glob.glob(os.path.join(IMG_DIR1, ext)))
sample_imgs = natsorted(sample_imgs)

print(f"[INFO] Found {len(sample_imgs)} images.")

# 클래스 이름 (학습할 때 쓴 순서와 맞춰야 함)
OC_NAMES = ["open", "close"]   # open/close 모델
FE_NAMES = ["empty", "full"]   # full/empty 모델

for img_path in sample_imgs:
    # 이미지 로드 (BGR -> RGB)
    img_bgr = cv2.imread(img_path)
    if img_bgr is None:
        print(f"[WARN] 이미지 로드 실패: {img_path}")
        continue
    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

    # -------- 1) 두 모델로 각각 추론 --------
    res_oc = model_oc(img_path, imgsz=640, conf=0.25)[0]
    res_fe = model_fe(img_path, imgsz=640, conf=0.25)[0]

    # 시각화용 복사본
    vis = img_rgb.copy()

    # -------- 2) open/close 박스 (얇은 초록색) --------
    if res_oc.boxes is not None and len(res_oc.boxes) > 0:
        for box, cls, conf in zip(res_oc.boxes.xyxy, res_oc.boxes.cls, res_oc.boxes.conf):
            x1, y1, x2, y2 = box.tolist()
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)

            cls_idx = int(cls.item())
            label = f"OC:{OC_NAMES[cls_idx]} {conf.item():.2f}"

            # 얇은 초록색 박스
            cv2.rectangle(
                vis,
                (x1, y1),
                (x2, y2),
                color=(0, 255, 0),   # BGR in cv2, but vis is RGB라 상관 없음 (색만 맞추면 됨)
                thickness=2
            )
            # 라벨 텍스트 (박스 위에)
            cv2.putText(
                vis,
                label,
                (x1, max(y1 - 5, 0)),
                cv2.FONT_HERSHEY_SIMPLEX,
                0.6,
                (0, 255, 0),
                2,
                cv2.LINE_AA
            )

    # -------- 3) full/empty 박스 (두꺼운 빨간색) --------
    if res_fe.boxes is not None and len(res_fe.boxes) > 0:
        for box, cls, conf in zip(res_fe.boxes.xyxy, res_fe.boxes.cls, res_fe.boxes.conf):
            x1, y1, x2, y2 = box.tolist()
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)

            cls_idx = int(cls.item())
            label = f"FE:{FE_NAMES[cls_idx]} {conf.item():.2f}"

            # 더 두꺼운 빨간색 박스
            cv2.rectangle(
                vis,
                (x1, y1),
                (x2, y2),
                color=(255, 0, 0),   # BGR
                thickness=4
            )
            # 라벨 텍스트 (박스 아래쪽에)
            cv2.putText(
                vis,
                label,
                (x1, min(y2 + 20, vis.shape[0] - 5)),
                cv2.FONT_HERSHEY_SIMPLEX,
                0.6,
                (255, 0, 0),
                2,
                cv2.LINE_AA
            )

    # -------- 4) 시각화 결과 저장 + 필요 시 화면에도 표시 --------
    out_name = os.path.basename(img_path)
    out_path = os.path.join(OUT_OC_FE_DIR, out_name)

    # vis는 RGB라 BGR로 변환 후 저장
    vis_bgr = cv2.cvtColor(vis, cv2.COLOR_RGB2BGR)
    cv2.imwrite(out_path, vis_bgr)
    print(f"[INFO] Saved vis image: {out_path}")

    # 필요하면 바로 plt로 보여주기
    # plt.figure(figsize=(6, 6))
    # plt.title(os.path.basename(img_path))
    # plt.imshow(vis)
    # plt.axis('off')
    # plt.show()
# Out:
# [INFO] Found 235 images.
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000000.jpg: 384x640 (no detections), 92.1ms
# Speed: 1.4ms preprocess, 92.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000000.jpg: 384x640 1 full, 66.0ms
# Speed: 1.1ms preprocess, 66.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000000.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000001.jpg: 384x640 (no detections), 70.5ms
# Speed: 1.2ms preprocess, 70.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000001.jpg: 384x640 1 full, 52.5ms
# Speed: 1.2ms preprocess, 52.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000001.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000002.jpg: 384x640 (no detections), 76.1ms
# Speed: 1.3ms preprocess, 76.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000002.jpg: 384x640 1 full, 59.2ms
# Speed: 1.3ms preprocess, 59.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000002.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000003.jpg: 384x640 (no detections), 56.0ms
# Speed: 1.2ms preprocess, 56.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000003.jpg: 384x640 1 full, 60.3ms
# Speed: 1.2ms preprocess, 60.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000003.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000004.jpg: 384x640 (no detections), 69.7ms
# Speed: 1.3ms preprocess, 69.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000004.jpg: 384x640 2 fulls, 61.6ms
# Speed: 1.2ms preprocess, 61.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000004.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000005.jpg: 384x640 1 open, 56.9ms
# Speed: 1.2ms preprocess, 56.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000005.jpg: 384x640 2 fulls, 71.6ms
# Speed: 1.2ms preprocess, 71.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000005.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000006.jpg: 384x640 1 open, 54.4ms
# Speed: 1.5ms preprocess, 54.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000006.jpg: 384x640 1 full, 60.5ms
# Speed: 1.2ms preprocess, 60.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000006.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000007.jpg: 384x640 1 open, 51.5ms
# Speed: 1.3ms preprocess, 51.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000007.jpg: 384x640 (no detections), 59.1ms
# Speed: 1.1ms preprocess, 59.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000007.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000008.jpg: 384x640 1 open, 54.1ms
# Speed: 1.1ms preprocess, 54.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000008.jpg: 384x640 1 full, 51.5ms
# Speed: 1.4ms preprocess, 51.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000008.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000009.jpg: 384x640 1 open, 48.4ms
# Speed: 1.6ms preprocess, 48.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000009.jpg: 384x640 1 full, 49.2ms
# Speed: 1.2ms preprocess, 49.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000009.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000010.jpg: 384x640 2 opens, 54.1ms
# Speed: 1.2ms preprocess, 54.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000010.jpg: 384x640 1 full, 52.2ms
# Speed: 1.1ms preprocess, 52.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000010.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000011.jpg: 384x640 (no detections), 58.4ms
# Speed: 1.5ms preprocess, 58.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000011.jpg: 384x640 1 full, 71.7ms
# Speed: 1.4ms preprocess, 71.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000011.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000012.jpg: 384x640 (no detections), 56.5ms
# Speed: 1.3ms preprocess, 56.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000012.jpg: 384x640 1 full, 50.0ms
# Speed: 1.3ms preprocess, 50.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000012.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000013.jpg: 384x640 (no detections), 49.4ms
# Speed: 1.1ms preprocess, 49.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000013.jpg: 384x640 1 full, 50.2ms
# Speed: 1.2ms preprocess, 50.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000013.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000014.jpg: 384x640 1 open, 50.8ms
# Speed: 1.2ms preprocess, 50.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000014.jpg: 384x640 1 full, 54.8ms
# Speed: 1.5ms preprocess, 54.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000014.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000015.jpg: 384x640 (no detections), 52.6ms
# Speed: 1.3ms preprocess, 52.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000015.jpg: 384x640 1 full, 63.5ms
# Speed: 25.1ms preprocess, 63.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000015.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000016.jpg: 384x640 (no detections), 52.8ms
# Speed: 1.2ms preprocess, 52.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000016.jpg: 384x640 1 full, 72.6ms
# Speed: 1.6ms preprocess, 72.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000016.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000017.jpg: 384x640 (no detections), 52.8ms
# Speed: 1.3ms preprocess, 52.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000017.jpg: 384x640 (no detections), 49.6ms
# Speed: 1.2ms preprocess, 49.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000017.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000018.jpg: 384x640 1 open, 53.5ms
# Speed: 1.2ms preprocess, 53.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000018.jpg: 384x640 2 fulls, 55.0ms
# Speed: 1.3ms preprocess, 55.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000018.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000019.jpg: 384x640 (no detections), 64.3ms
# Speed: 1.2ms preprocess, 64.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000019.jpg: 384x640 (no detections), 57.2ms
# Speed: 1.2ms preprocess, 57.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000019.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000020.jpg: 384x640 (no detections), 56.7ms
# Speed: 1.3ms preprocess, 56.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000020.jpg: 384x640 (no detections), 55.1ms
# Speed: 1.2ms preprocess, 55.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000020.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000021.jpg: 384x640 (no detections), 53.1ms
# Speed: 1.6ms preprocess, 53.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000021.jpg: 384x640 (no detections), 72.9ms
# Speed: 1.5ms preprocess, 72.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000021.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000022.jpg: 384x640 (no detections), 53.3ms
# Speed: 1.4ms preprocess, 53.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000022.jpg: 384x640 (no detections), 53.7ms
# Speed: 1.1ms preprocess, 53.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000022.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000023.jpg: 384x640 (no detections), 53.0ms
# Speed: 1.3ms preprocess, 53.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000023.jpg: 384x640 2 fulls, 54.5ms
# Speed: 1.2ms preprocess, 54.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000023.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000024.jpg: 384x640 (no detections), 55.2ms
# Speed: 1.2ms preprocess, 55.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000024.jpg: 384x640 (no detections), 56.0ms
# Speed: 1.2ms preprocess, 56.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000024.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000025.jpg: 384x640 2 opens, 54.9ms
# Speed: 1.3ms preprocess, 54.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000025.jpg: 384x640 1 full, 53.6ms
# Speed: 1.2ms preprocess, 53.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000025.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000026.jpg: 384x640 (no detections), 52.7ms
# Speed: 1.2ms preprocess, 52.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000026.jpg: 384x640 (no detections), 53.8ms
# Speed: 1.2ms preprocess, 53.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000026.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000027.jpg: 384x640 1 open, 53.4ms
# Speed: 1.2ms preprocess, 53.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000027.jpg: 384x640 (no detections), 55.2ms
# Speed: 1.1ms preprocess, 55.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000027.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000028.jpg: 384x640 1 open, 100.0ms
# Speed: 1.4ms preprocess, 100.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000028.jpg: 384x640 (no detections), 61.6ms
# Speed: 1.2ms preprocess, 61.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000028.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000029.jpg: 384x640 (no detections), 78.0ms
# Speed: 2.5ms preprocess, 78.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000029.jpg: 384x640 (no detections), 63.2ms
# Speed: 1.9ms preprocess, 63.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000029.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000030.jpg: 384x640 (no detections), 52.0ms
# Speed: 1.6ms preprocess, 52.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000030.jpg: 384x640 (no detections), 54.1ms
# Speed: 1.1ms preprocess, 54.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000030.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000031.jpg: 384x640 (no detections), 72.1ms
# Speed: 1.3ms preprocess, 72.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000031.jpg: 384x640 (no detections), 73.1ms
# Speed: 2.0ms preprocess, 73.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000031.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000032.jpg: 384x640 (no detections), 71.4ms
# Speed: 1.6ms preprocess, 71.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000032.jpg: 384x640 (no detections), 64.1ms
# Speed: 1.6ms preprocess, 64.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000032.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000033.jpg: 384x640 1 open, 61.0ms
# Speed: 1.2ms preprocess, 61.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000033.jpg: 384x640 1 full, 67.4ms
# Speed: 1.2ms preprocess, 67.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000033.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000034.jpg: 384x640 1 open, 55.2ms
# Speed: 1.3ms preprocess, 55.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000034.jpg: 384x640 2 fulls, 54.0ms
# Speed: 1.2ms preprocess, 54.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000034.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000035.jpg: 384x640 (no detections), 48.6ms
# Speed: 1.2ms preprocess, 48.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000035.jpg: 384x640 1 full, 50.7ms
# Speed: 1.2ms preprocess, 50.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000035.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000036.jpg: 384x640 1 open, 52.1ms
# Speed: 1.3ms preprocess, 52.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000036.jpg: 384x640 3 fulls, 49.0ms
# Speed: 1.2ms preprocess, 49.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000036.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000037.jpg: 384x640 (no detections), 53.3ms
# Speed: 1.1ms preprocess, 53.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000037.jpg: 384x640 1 full, 53.0ms
# Speed: 1.2ms preprocess, 53.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000037.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000038.jpg: 384x640 1 open, 54.9ms
# Speed: 1.2ms preprocess, 54.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000038.jpg: 384x640 (no detections), 79.8ms
# Speed: 1.3ms preprocess, 79.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000038.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000039.jpg: 384x640 (no detections), 50.8ms
# Speed: 1.2ms preprocess, 50.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000039.jpg: 384x640 (no detections), 53.4ms
# Speed: 1.1ms preprocess, 53.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000039.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000040.jpg: 384x640 (no detections), 66.5ms
# Speed: 36.2ms preprocess, 66.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000040.jpg: 384x640 (no detections), 59.9ms
# Speed: 1.2ms preprocess, 59.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000040.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000041.jpg: 384x640 (no detections), 50.3ms
# Speed: 1.3ms preprocess, 50.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000041.jpg: 384x640 (no detections), 50.8ms
# Speed: 1.1ms preprocess, 50.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000041.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000042.jpg: 384x640 (no detections), 54.7ms
# Speed: 1.3ms preprocess, 54.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000042.jpg: 384x640 1 full, 56.8ms
# Speed: 1.1ms preprocess, 56.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000042.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000043.jpg: 384x640 (no detections), 65.7ms
# Speed: 1.2ms preprocess, 65.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000043.jpg: 384x640 (no detections), 58.8ms
# Speed: 1.8ms preprocess, 58.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000043.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000044.jpg: 384x640 (no detections), 49.7ms
# Speed: 1.2ms preprocess, 49.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000044.jpg: 384x640 (no detections), 53.8ms
# Speed: 1.4ms preprocess, 53.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000044.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000045.jpg: 384x640 1 close, 56.2ms
# Speed: 1.1ms preprocess, 56.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000045.jpg: 384x640 1 empty, 63.7ms
# Speed: 1.3ms preprocess, 63.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000045.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000046.jpg: 384x640 1 close, 49.0ms
# Speed: 1.1ms preprocess, 49.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000046.jpg: 384x640 1 empty, 57.9ms
# Speed: 1.2ms preprocess, 57.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000046.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000047.jpg: 384x640 1 close, 53.5ms
# Speed: 1.3ms preprocess, 53.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000047.jpg: 384x640 1 empty, 1 full, 51.3ms
# Speed: 1.1ms preprocess, 51.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000047.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000048.jpg: 384x640 2 opens, 117.2ms
# Speed: 1.2ms preprocess, 117.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000048.jpg: 384x640 1 full, 88.5ms
# Speed: 1.4ms preprocess, 88.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000048.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000049.jpg: 384x640 2 opens, 76.0ms
# Speed: 1.9ms preprocess, 76.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000049.jpg: 384x640 2 fulls, 52.8ms
# Speed: 1.2ms preprocess, 52.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000049.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000050.jpg: 384x640 1 open, 55.0ms
# Speed: 1.1ms preprocess, 55.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000050.jpg: 384x640 1 full, 67.3ms
# Speed: 1.1ms preprocess, 67.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000050.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000051.jpg: 384x640 1 open, 62.4ms
# Speed: 1.7ms preprocess, 62.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000051.jpg: 384x640 2 fulls, 58.8ms
# Speed: 1.2ms preprocess, 58.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000051.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000052.jpg: 384x640 1 open, 76.9ms
# Speed: 1.4ms preprocess, 76.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000052.jpg: 384x640 2 fulls, 63.4ms
# Speed: 1.3ms preprocess, 63.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000052.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000053.jpg: 384x640 1 open, 57.0ms
# Speed: 1.1ms preprocess, 57.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000053.jpg: 384x640 1 full, 71.3ms
# Speed: 1.3ms preprocess, 71.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000053.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000054.jpg: 384x640 1 open, 55.1ms
# Speed: 1.1ms preprocess, 55.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000054.jpg: 384x640 1 full, 56.4ms
# Speed: 1.1ms preprocess, 56.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000054.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000055.jpg: 384x640 1 open, 56.0ms
# Speed: 1.1ms preprocess, 56.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000055.jpg: 384x640 1 full, 54.0ms
# Speed: 1.2ms preprocess, 54.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000055.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000056.jpg: 384x640 1 open, 57.8ms
# Speed: 1.3ms preprocess, 57.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000056.jpg: 384x640 1 full, 56.4ms
# Speed: 1.1ms preprocess, 56.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000056.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000057.jpg: 384x640 1 open, 51.0ms
# Speed: 1.1ms preprocess, 51.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000057.jpg: 384x640 1 full, 51.5ms
# Speed: 1.1ms preprocess, 51.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000057.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000058.jpg: 384x640 1 open, 50.5ms
# Speed: 1.7ms preprocess, 50.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000058.jpg: 384x640 (no detections), 55.1ms
# Speed: 1.1ms preprocess, 55.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000058.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000059.jpg: 384x640 1 open, 51.3ms
# Speed: 1.4ms preprocess, 51.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000059.jpg: 384x640 (no detections), 55.7ms
# Speed: 1.2ms preprocess, 55.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000059.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000060.jpg: 384x640 1 open, 48.5ms
# Speed: 1.5ms preprocess, 48.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000060.jpg: 384x640 (no detections), 51.9ms
# Speed: 1.1ms preprocess, 51.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000060.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000061.jpg: 384x640 1 open, 50.7ms
# Speed: 1.3ms preprocess, 50.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000061.jpg: 384x640 1 full, 51.6ms
# Speed: 1.2ms preprocess, 51.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000061.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000062.jpg: 384x640 1 open, 55.7ms
# Speed: 15.0ms preprocess, 55.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000062.jpg: 384x640 1 full, 53.6ms
# Speed: 1.2ms preprocess, 53.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000062.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000063.jpg: 384x640 1 open, 48.7ms
# Speed: 1.2ms preprocess, 48.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000063.jpg: 384x640 1 full, 55.1ms
# Speed: 1.1ms preprocess, 55.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000063.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000064.jpg: 384x640 2 opens, 54.9ms
# Speed: 2.1ms preprocess, 54.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000064.jpg: 384x640 1 full, 109.2ms
# Speed: 1.1ms preprocess, 109.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000064.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000065.jpg: 384x640 2 opens, 49.8ms
# Speed: 1.1ms preprocess, 49.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000065.jpg: 384x640 2 fulls, 51.9ms
# Speed: 1.1ms preprocess, 51.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000065.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000066.jpg: 384x640 3 opens, 48.6ms
# Speed: 1.3ms preprocess, 48.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000066.jpg: 384x640 3 fulls, 54.6ms
# Speed: 1.4ms preprocess, 54.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000066.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000067.jpg: 384x640 2 opens, 50.2ms
# Speed: 1.1ms preprocess, 50.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000067.jpg: 384x640 1 full, 53.5ms
# Speed: 1.2ms preprocess, 53.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000067.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000068.jpg: 384x640 2 opens, 54.9ms
# Speed: 1.2ms preprocess, 54.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000068.jpg: 384x640 1 empty, 54.0ms
# Speed: 1.2ms preprocess, 54.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000068.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000069.jpg: 384x640 2 opens, 70.6ms
# Speed: 1.1ms preprocess, 70.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000069.jpg: 384x640 1 empty, 1 full, 68.6ms
# Speed: 1.2ms preprocess, 68.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000069.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000070.jpg: 384x640 2 opens, 54.9ms
# Speed: 1.3ms preprocess, 54.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000070.jpg: 384x640 1 full, 57.8ms
# Speed: 1.1ms preprocess, 57.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000070.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000071.jpg: 384x640 2 opens, 72.1ms
# Speed: 1.1ms preprocess, 72.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000071.jpg: 384x640 1 empty, 1 full, 63.5ms
# Speed: 1.1ms preprocess, 63.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000071.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000072.jpg: 384x640 2 opens, 51.0ms
# Speed: 1.2ms preprocess, 51.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000072.jpg: 384x640 1 empty, 1 full, 59.2ms
# Speed: 1.2ms preprocess, 59.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000072.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000073.jpg: 384x640 2 opens, 49.1ms
# Speed: 1.2ms preprocess, 49.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000073.jpg: 384x640 1 empty, 1 full, 52.4ms
# Speed: 1.1ms preprocess, 52.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000073.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000074.jpg: 384x640 2 opens, 51.7ms
# Speed: 1.3ms preprocess, 51.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000074.jpg: 384x640 2 emptys, 59.6ms
# Speed: 1.1ms preprocess, 59.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000074.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000075.jpg: 384x640 2 opens, 53.6ms
# Speed: 1.1ms preprocess, 53.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000075.jpg: 384x640 1 empty, 51.1ms
# Speed: 1.2ms preprocess, 51.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000075.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000076.jpg: 384x640 1 open, 63.0ms
# Speed: 31.6ms preprocess, 63.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000076.jpg: 384x640 1 empty, 59.6ms
# Speed: 1.1ms preprocess, 59.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000076.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000077.jpg: 384x640 1 open, 53.9ms
# Speed: 1.2ms preprocess, 53.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000077.jpg: 384x640 1 empty, 2 fulls, 58.2ms
# Speed: 1.1ms preprocess, 58.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000077.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000078.jpg: 384x640 3 opens, 49.7ms
# Speed: 1.2ms preprocess, 49.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000078.jpg: 384x640 2 emptys, 2 fulls, 52.2ms
# Speed: 1.2ms preprocess, 52.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000078.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000079.jpg: 384x640 3 opens, 47.6ms
# Speed: 1.3ms preprocess, 47.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000079.jpg: 384x640 3 fulls, 50.8ms
# Speed: 1.1ms preprocess, 50.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000079.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000080.jpg: 384x640 4 opens, 51.8ms
# Speed: 1.2ms preprocess, 51.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000080.jpg: 384x640 3 emptys, 2 fulls, 51.4ms
# Speed: 1.1ms preprocess, 51.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000080.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000081.jpg: 384x640 4 opens, 60.2ms
# Speed: 16.8ms preprocess, 60.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000081.jpg: 384x640 3 emptys, 2 fulls, 60.9ms
# Speed: 1.1ms preprocess, 60.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000081.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000082.jpg: 384x640 3 opens, 53.8ms
# Speed: 1.2ms preprocess, 53.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000082.jpg: 384x640 2 emptys, 1 full, 52.1ms
# Speed: 1.2ms preprocess, 52.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000082.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000083.jpg: 384x640 2 opens, 54.3ms
# Speed: 1.3ms preprocess, 54.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000083.jpg: 384x640 2 emptys, 1 full, 60.8ms
# Speed: 1.2ms preprocess, 60.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000083.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000084.jpg: 384x640 3 opens, 62.1ms
# Speed: 1.2ms preprocess, 62.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000084.jpg: 384x640 1 empty, 2 fulls, 67.9ms
# Speed: 1.2ms preprocess, 67.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000084.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000085.jpg: 384x640 3 opens, 65.4ms
# Speed: 1.4ms preprocess, 65.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000085.jpg: 384x640 1 full, 60.4ms
# Speed: 1.2ms preprocess, 60.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000085.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000086.jpg: 384x640 2 opens, 53.5ms
# Speed: 1.6ms preprocess, 53.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000086.jpg: 384x640 1 empty, 2 fulls, 59.5ms
# Speed: 1.4ms preprocess, 59.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000086.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000087.jpg: 384x640 2 opens, 66.8ms
# Speed: 3.4ms preprocess, 66.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000087.jpg: 384x640 2 emptys, 1 full, 55.6ms
# Speed: 1.1ms preprocess, 55.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000087.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000088.jpg: 384x640 2 opens, 56.8ms
# Speed: 1.3ms preprocess, 56.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000088.jpg: 384x640 2 emptys, 2 fulls, 57.3ms
# Speed: 1.2ms preprocess, 57.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000088.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000089.jpg: 384x640 2 opens, 72.0ms
# Speed: 1.3ms preprocess, 72.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000089.jpg: 384x640 2 emptys, 2 fulls, 73.9ms
# Speed: 1.3ms preprocess, 73.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000089.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000090.jpg: 384x640 2 opens, 59.0ms
# Speed: 1.1ms preprocess, 59.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000090.jpg: 384x640 2 fulls, 60.9ms
# Speed: 1.2ms preprocess, 60.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000090.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000091.jpg: 384x640 2 opens, 92.3ms
# Speed: 5.4ms preprocess, 92.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000091.jpg: 384x640 3 fulls, 67.0ms
# Speed: 1.3ms preprocess, 67.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000091.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000092.jpg: 384x640 2 opens, 86.0ms
# Speed: 6.8ms preprocess, 86.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000092.jpg: 384x640 2 emptys, 2 fulls, 70.3ms
# Speed: 1.8ms preprocess, 70.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000092.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000093.jpg: 384x640 3 opens, 64.4ms
# Speed: 1.5ms preprocess, 64.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
# Speed: 1.3ms preprocess, 72.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000204.jpg: 384x640 2 fulls, 65.4ms
# Speed: 1.3ms preprocess, 65.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000204.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000205.jpg: 384x640 1 open, 68.8ms
# Speed: 1.5ms preprocess, 68.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000205.jpg: 384x640 2 fulls, 73.3ms
# Speed: 2.7ms preprocess, 73.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000205.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000206.jpg: 384x640 (no detections), 67.4ms
# Speed: 2.4ms preprocess, 67.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000206.jpg: 384x640 1 full, 66.9ms
# Speed: 2.3ms preprocess, 66.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000206.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000207.jpg: 384x640 (no detections), 88.2ms
# Speed: 1.6ms preprocess, 88.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000207.jpg: 384x640 1 full, 76.4ms
# Speed: 1.8ms preprocess, 76.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000207.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000208.jpg: 384x640 (no detections), 73.0ms
# Speed: 1.2ms preprocess, 73.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000208.jpg: 384x640 (no detections), 86.0ms
# Speed: 1.8ms preprocess, 86.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000208.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000209.jpg: 384x640 (no detections), 67.9ms
# Speed: 1.2ms preprocess, 67.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000209.jpg: 384x640 1 full, 67.2ms
# Speed: 1.2ms preprocess, 67.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000209.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000210.jpg: 384x640 (no detections), 70.8ms
# Speed: 2.9ms preprocess, 70.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000210.jpg: 384x640 (no detections), 194.1ms
# Speed: 1.6ms preprocess, 194.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000210.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000211.jpg: 384x640 (no detections), 72.9ms
# Speed: 2.0ms preprocess, 72.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000211.jpg: 384x640 (no detections), 67.6ms
# Speed: 1.2ms preprocess, 67.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000211.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000212.jpg: 384x640 (no detections), 69.1ms
# Speed: 1.3ms preprocess, 69.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000212.jpg: 384x640 (no detections), 66.4ms
# Speed: 1.2ms preprocess, 66.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000212.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000213.jpg: 384x640 (no detections), 81.6ms
# Speed: 3.2ms preprocess, 81.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000213.jpg: 384x640 (no detections), 85.8ms
# Speed: 1.6ms preprocess, 85.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000213.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000214.jpg: 384x640 (no detections), 79.9ms
# Speed: 1.4ms preprocess, 79.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000214.jpg: 384x640 (no detections), 65.8ms
# Speed: 1.2ms preprocess, 65.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000214.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000215.jpg: 384x640 (no detections), 68.5ms
# Speed: 2.5ms preprocess, 68.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000215.jpg: 384x640 (no detections), 87.5ms
# Speed: 1.5ms preprocess, 87.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000215.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000216.jpg: 384x640 (no detections), 65.0ms
# Speed: 1.6ms preprocess, 65.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000216.jpg: 384x640 (no detections), 62.4ms
# Speed: 1.1ms preprocess, 62.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000216.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000217.jpg: 384x640 (no detections), 101.6ms
# Speed: 2.4ms preprocess, 101.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000217.jpg: 384x640 1 full, 66.4ms
# Speed: 1.3ms preprocess, 66.4ms inference, 19.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000217.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000218.jpg: 384x640 (no detections), 74.0ms
# Speed: 2.3ms preprocess, 74.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000218.jpg: 384x640 (no detections), 69.0ms
# Speed: 2.0ms preprocess, 69.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000218.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000219.jpg: 384x640 (no detections), 65.9ms
# Speed: 2.3ms preprocess, 65.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000219.jpg: 384x640 (no detections), 63.7ms
# Speed: 1.9ms preprocess, 63.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000219.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000220.jpg: 384x640 (no detections), 76.9ms
# Speed: 1.8ms preprocess, 76.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000220.jpg: 384x640 (no detections), 107.4ms
# Speed: 1.9ms preprocess, 107.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000220.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000221.jpg: 384x640 (no detections), 68.2ms
# Speed: 1.6ms preprocess, 68.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000221.jpg: 384x640 1 full, 65.7ms
# Speed: 2.0ms preprocess, 65.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000221.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000222.jpg: 384x640 (no detections), 65.2ms
# Speed: 1.9ms preprocess, 65.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000222.jpg: 384x640 (no detections), 76.2ms
# Speed: 1.3ms preprocess, 76.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000222.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000223.jpg: 384x640 (no detections), 73.5ms
# Speed: 1.5ms preprocess, 73.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000223.jpg: 384x640 (no detections), 69.1ms
# Speed: 1.1ms preprocess, 69.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000223.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000224.jpg: 384x640 (no detections), 66.3ms
# Speed: 1.3ms preprocess, 66.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000224.jpg: 384x640 1 full, 69.9ms
# Speed: 2.7ms preprocess, 69.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000224.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000225.jpg: 384x640 (no detections), 78.2ms
# Speed: 19.4ms preprocess, 78.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000225.jpg: 384x640 2 fulls, 65.4ms
# Speed: 1.2ms preprocess, 65.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000225.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000226.jpg: 384x640 1 open, 67.6ms
# Speed: 2.7ms preprocess, 67.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000226.jpg: 384x640 1 full, 65.8ms
# Speed: 1.2ms preprocess, 65.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000226.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000227.jpg: 384x640 (no detections), 68.0ms
# Speed: 1.8ms preprocess, 68.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000227.jpg: 384x640 (no detections), 87.3ms
# Speed: 2.2ms preprocess, 87.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000227.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000228.jpg: 384x640 (no detections), 75.9ms
# Speed: 2.6ms preprocess, 75.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000228.jpg: 384x640 (no detections), 67.6ms
# Speed: 1.4ms preprocess, 67.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000228.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000229.jpg: 384x640 (no detections), 68.9ms
# Speed: 5.2ms preprocess, 68.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000229.jpg: 384x640 (no detections), 65.5ms
# Speed: 1.8ms preprocess, 65.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000229.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000230.jpg: 384x640 (no detections), 67.4ms
# Speed: 2.2ms preprocess, 67.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000230.jpg: 384x640 (no detections), 59.9ms
# Speed: 2.7ms preprocess, 59.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000230.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000231.jpg: 384x640 (no detections), 60.8ms
# Speed: 2.0ms preprocess, 60.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000231.jpg: 384x640 (no detections), 57.6ms
# Speed: 1.8ms preprocess, 57.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000231.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000232.jpg: 384x640 (no detections), 84.7ms
# Speed: 2.1ms preprocess, 84.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000232.jpg: 384x640 (no detections), 71.6ms
# Speed: 1.9ms preprocess, 71.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000232.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000233.jpg: 384x640 (no detections), 76.8ms
# Speed: 2.7ms preprocess, 76.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000233.jpg: 384x640 (no detections), 83.1ms
# Speed: 1.9ms preprocess, 83.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000233.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000234.jpg: 384x640 (no detections), 64.4ms
# Speed: 2.2ms preprocess, 64.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_002(fast)\frame_000234.jpg: 384x640 (no detections), 65.8ms
# Speed: 1.9ms preprocess, 65.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000234.jpg

# %%
# ===== 샘플 이미지 목록 =====
sample_imgs = []
for ext in ("*.jpg", "*.png"):
    sample_imgs.extend(glob.glob(os.path.join(IMG_DIR2, ext)))
sample_imgs = natsorted(sample_imgs)

print(f"[INFO] Found {len(sample_imgs)} images.")

# 클래스 이름 (학습할 때 쓴 순서와 맞춰야 함)
OC_NAMES = ["open", "close"]   # open/close 모델
FE_NAMES = ["empty", "full"]   # full/empty 모델

for img_path in sample_imgs:
    # 이미지 로드 (BGR -> RGB)
    img_bgr = cv2.imread(img_path)
    if img_bgr is None:
        print(f"[WARN] 이미지 로드 실패: {img_path}")
        continue
    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

    # -------- 1) 두 모델로 각각 추론 --------
    res_oc = model_oc(img_path, imgsz=640, conf=0.25)[0]
    res_fe = model_fe(img_path, imgsz=640, conf=0.25)[0]

    # 시각화용 복사본
    vis = img_rgb.copy()

    # -------- 2) open/close 박스 (얇은 초록색) --------
    if res_oc.boxes is not None and len(res_oc.boxes) > 0:
        for box, cls, conf in zip(res_oc.boxes.xyxy, res_oc.boxes.cls, res_oc.boxes.conf):
            x1, y1, x2, y2 = box.tolist()
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)

            cls_idx = int(cls.item())
            label = f"OC:{OC_NAMES[cls_idx]} {conf.item():.2f}"

            # 얇은 초록색 박스
            cv2.rectangle(
                vis,
                (x1, y1),
                (x2, y2),
                color=(0, 255, 0),   # BGR in cv2, but vis is RGB라 상관 없음 (색만 맞추면 됨)
                thickness=2
            )
            # 라벨 텍스트 (박스 위에)
            cv2.putText(
                vis,
                label,
                (x1, max(y1 - 5, 0)),
                cv2.FONT_HERSHEY_SIMPLEX,
                0.6,
                (0, 255, 0),
                2,
                cv2.LINE_AA
            )

    # -------- 3) full/empty 박스 (두꺼운 빨간색) --------
    if res_fe.boxes is not None and len(res_fe.boxes) > 0:
        for box, cls, conf in zip(res_fe.boxes.xyxy, res_fe.boxes.cls, res_fe.boxes.conf):
            x1, y1, x2, y2 = box.tolist()
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)

            cls_idx = int(cls.item())
            label = f"FE:{FE_NAMES[cls_idx]} {conf.item():.2f}"

            # 더 두꺼운 빨간색 박스
            cv2.rectangle(
                vis,
                (x1, y1),
                (x2, y2),
                color=(255, 0, 0),   # BGR
                thickness=4
            )
            # 라벨 텍스트 (박스 아래쪽에)
            cv2.putText(
                vis,
                label,
                (x1, min(y2 + 20, vis.shape[0] - 5)),
                cv2.FONT_HERSHEY_SIMPLEX,
                0.6,
                (255, 0, 0),
                2,
                cv2.LINE_AA
            )

    # -------- 4) 시각화 결과 저장 + 필요 시 화면에도 표시 --------
    out_name = os.path.basename(img_path)
    out_path = os.path.join(OUT_OC_FE_DIR, out_name)

    # vis는 RGB라 BGR로 변환 후 저장
    vis_bgr = cv2.cvtColor(vis, cv2.COLOR_RGB2BGR)
    cv2.imwrite(out_path, vis_bgr)
    print(f"[INFO] Saved vis image: {out_path}")

    # 필요하면 바로 plt로 보여주기
    # plt.figure(figsize=(6, 6))
    # plt.title(os.path.basename(img_path))
    # plt.imshow(vis)
    # plt.axis('off')
    # plt.show()
# Out:
# [INFO] Found 452 images.
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000000.jpg: 384x640 (no detections), 83.4ms
# Speed: 1.3ms preprocess, 83.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000000.jpg: 384x640 (no detections), 62.7ms
# Speed: 1.8ms preprocess, 62.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000000.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000001.jpg: 384x640 (no detections), 60.9ms
# Speed: 3.3ms preprocess, 60.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000001.jpg: 384x640 (no detections), 58.3ms
# Speed: 1.1ms preprocess, 58.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000001.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000002.jpg: 384x640 (no detections), 67.7ms
# Speed: 1.3ms preprocess, 67.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000002.jpg: 384x640 (no detections), 62.8ms
# Speed: 2.2ms preprocess, 62.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000002.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000003.jpg: 384x640 (no detections), 66.3ms
# Speed: 1.2ms preprocess, 66.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000003.jpg: 384x640 (no detections), 58.5ms
# Speed: 1.1ms preprocess, 58.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000003.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000004.jpg: 384x640 (no detections), 63.7ms
# Speed: 2.6ms preprocess, 63.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000004.jpg: 384x640 (no detections), 56.3ms
# Speed: 1.1ms preprocess, 56.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000004.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000005.jpg: 384x640 (no detections), 68.7ms
# Speed: 1.3ms preprocess, 68.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000005.jpg: 384x640 (no detections), 61.1ms
# Speed: 1.1ms preprocess, 61.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000005.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000006.jpg: 384x640 (no detections), 59.1ms
# Speed: 2.1ms preprocess, 59.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000006.jpg: 384x640 (no detections), 58.6ms
# Speed: 1.1ms preprocess, 58.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000006.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000007.jpg: 384x640 (no detections), 67.5ms
# Speed: 1.4ms preprocess, 67.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000007.jpg: 384x640 (no detections), 63.2ms
# Speed: 1.2ms preprocess, 63.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000007.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000008.jpg: 384x640 (no detections), 61.8ms
# Speed: 1.3ms preprocess, 61.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000008.jpg: 384x640 (no detections), 55.8ms
# Speed: 1.1ms preprocess, 55.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000008.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000009.jpg: 384x640 (no detections), 78.7ms
# Speed: 1.7ms preprocess, 78.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000009.jpg: 384x640 (no detections), 57.6ms
# Speed: 1.3ms preprocess, 57.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000009.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000010.jpg: 384x640 (no detections), 69.5ms
# Speed: 1.3ms preprocess, 69.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000010.jpg: 384x640 (no detections), 64.8ms
# Speed: 1.2ms preprocess, 64.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000010.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000011.jpg: 384x640 (no detections), 110.9ms
# Speed: 1.2ms preprocess, 110.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000011.jpg: 384x640 (no detections), 59.3ms
# Speed: 6.2ms preprocess, 59.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000011.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000012.jpg: 384x640 (no detections), 62.3ms
# Speed: 1.1ms preprocess, 62.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000012.jpg: 384x640 (no detections), 69.9ms
# Speed: 1.1ms preprocess, 69.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000012.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000013.jpg: 384x640 (no detections), 66.1ms
# Speed: 1.2ms preprocess, 66.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000013.jpg: 384x640 (no detections), 55.6ms
# Speed: 1.1ms preprocess, 55.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000013.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000014.jpg: 384x640 (no detections), 65.9ms
# Speed: 1.3ms preprocess, 65.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000014.jpg: 384x640 (no detections), 62.5ms
# Speed: 1.8ms preprocess, 62.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000014.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000015.jpg: 384x640 (no detections), 59.3ms
# Speed: 1.5ms preprocess, 59.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000015.jpg: 384x640 (no detections), 56.6ms
# Speed: 1.4ms preprocess, 56.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000015.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000016.jpg: 384x640 (no detections), 59.6ms
# Speed: 1.5ms preprocess, 59.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000016.jpg: 384x640 (no detections), 56.9ms
# Speed: 1.1ms preprocess, 56.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000016.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000017.jpg: 384x640 (no detections), 68.0ms
# Speed: 1.3ms preprocess, 68.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000017.jpg: 384x640 (no detections), 69.7ms
# Speed: 1.3ms preprocess, 69.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000017.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000018.jpg: 384x640 (no detections), 60.2ms
# Speed: 1.2ms preprocess, 60.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000018.jpg: 384x640 (no detections), 56.0ms
# Speed: 1.3ms preprocess, 56.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000018.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000019.jpg: 384x640 (no detections), 65.5ms
# Speed: 1.2ms preprocess, 65.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000019.jpg: 384x640 (no detections), 62.5ms
# Speed: 1.1ms preprocess, 62.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000019.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000020.jpg: 384x640 (no detections), 76.8ms
# Speed: 1.6ms preprocess, 76.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000020.jpg: 384x640 (no detections), 61.4ms
# Speed: 1.1ms preprocess, 61.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000020.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000021.jpg: 384x640 (no detections), 129.6ms
# Speed: 1.3ms preprocess, 129.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000021.jpg: 384x640 (no detections), 62.2ms
# Speed: 1.3ms preprocess, 62.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000021.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000022.jpg: 384x640 (no detections), 61.3ms
# Speed: 1.2ms preprocess, 61.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000022.jpg: 384x640 (no detections), 60.9ms
# Speed: 1.3ms preprocess, 60.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000022.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000023.jpg: 384x640 (no detections), 62.5ms
# Speed: 1.3ms preprocess, 62.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000023.jpg: 384x640 (no detections), 64.4ms
# Speed: 1.1ms preprocess, 64.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000023.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000024.jpg: 384x640 1 open, 65.1ms
# Speed: 1.1ms preprocess, 65.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000024.jpg: 384x640 (no detections), 58.7ms
# Speed: 1.2ms preprocess, 58.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000024.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000025.jpg: 384x640 1 open, 72.8ms
# Speed: 1.3ms preprocess, 72.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000025.jpg: 384x640 (no detections), 78.7ms
# Speed: 1.3ms preprocess, 78.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000025.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000026.jpg: 384x640 2 opens, 64.0ms
# Speed: 2.3ms preprocess, 64.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000026.jpg: 384x640 (no detections), 72.2ms
# Speed: 1.2ms preprocess, 72.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000026.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000027.jpg: 384x640 1 open, 62.1ms
# Speed: 1.8ms preprocess, 62.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000027.jpg: 384x640 (no detections), 69.0ms
# Speed: 1.2ms preprocess, 69.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000027.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000028.jpg: 384x640 (no detections), 60.9ms
# Speed: 1.3ms preprocess, 60.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000028.jpg: 384x640 (no detections), 60.7ms
# Speed: 1.2ms preprocess, 60.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000028.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000029.jpg: 384x640 1 open, 61.6ms
# Speed: 1.2ms preprocess, 61.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000029.jpg: 384x640 (no detections), 59.3ms
# Speed: 1.2ms preprocess, 59.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000029.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000030.jpg: 384x640 (no detections), 58.8ms
# Speed: 1.4ms preprocess, 58.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000030.jpg: 384x640 1 full, 62.6ms
# Speed: 1.1ms preprocess, 62.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000030.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000031.jpg: 384x640 (no detections), 66.5ms
# Speed: 1.5ms preprocess, 66.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000031.jpg: 384x640 1 full, 111.7ms
# Speed: 1.3ms preprocess, 111.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000031.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000032.jpg: 384x640 1 open, 71.8ms
# Speed: 1.3ms preprocess, 71.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000032.jpg: 384x640 (no detections), 61.2ms
# Speed: 1.3ms preprocess, 61.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000032.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000033.jpg: 384x640 1 open, 73.5ms
# Speed: 1.2ms preprocess, 73.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000033.jpg: 384x640 (no detections), 77.2ms
# Speed: 1.2ms preprocess, 77.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000033.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000034.jpg: 384x640 2 opens, 89.8ms
# Speed: 5.5ms preprocess, 89.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000034.jpg: 384x640 1 full, 81.4ms
# Speed: 1.3ms preprocess, 81.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000034.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000035.jpg: 384x640 1 open, 101.7ms
# Speed: 2.8ms preprocess, 101.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000035.jpg: 384x640 1 full, 66.1ms
# Speed: 1.5ms preprocess, 66.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000035.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000036.jpg: 384x640 1 open, 63.8ms
# Speed: 1.1ms preprocess, 63.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000036.jpg: 384x640 1 full, 62.2ms
# Speed: 1.2ms preprocess, 62.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000036.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000037.jpg: 384x640 3 opens, 68.8ms
# Speed: 1.2ms preprocess, 68.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000037.jpg: 384x640 (no detections), 165.6ms
# Speed: 1.2ms preprocess, 165.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000037.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000038.jpg: 384x640 (no detections), 85.0ms
# Speed: 1.2ms preprocess, 85.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000038.jpg: 384x640 1 full, 62.7ms
# Speed: 1.3ms preprocess, 62.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000038.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000039.jpg: 384x640 1 open, 55.5ms
# Speed: 1.2ms preprocess, 55.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000039.jpg: 384x640 (no detections), 51.7ms
# Speed: 1.2ms preprocess, 51.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000039.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000040.jpg: 384x640 2 opens, 80.5ms
# Speed: 3.1ms preprocess, 80.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000040.jpg: 384x640 (no detections), 69.2ms
# Speed: 1.3ms preprocess, 69.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000040.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000041.jpg: 384x640 2 opens, 86.4ms
# Speed: 1.3ms preprocess, 86.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000041.jpg: 384x640 (no detections), 69.4ms
# Speed: 1.3ms preprocess, 69.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000041.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000042.jpg: 384x640 1 open, 66.7ms
# Speed: 1.2ms preprocess, 66.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000042.jpg: 384x640 (no detections), 50.5ms
# Speed: 1.1ms preprocess, 50.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000042.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000043.jpg: 384x640 1 open, 61.9ms
# Speed: 4.4ms preprocess, 61.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000043.jpg: 384x640 1 full, 55.7ms
# Speed: 1.2ms preprocess, 55.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000043.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000044.jpg: 384x640 (no detections), 55.3ms
# Speed: 1.2ms preprocess, 55.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000044.jpg: 384x640 (no detections), 59.2ms
# Speed: 1.2ms preprocess, 59.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000044.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000045.jpg: 384x640 (no detections), 63.1ms
# Speed: 1.2ms preprocess, 63.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000045.jpg: 384x640 1 full, 50.4ms
# Speed: 1.1ms preprocess, 50.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000045.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000046.jpg: 384x640 (no detections), 57.7ms
# Speed: 1.4ms preprocess, 57.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000046.jpg: 384x640 (no detections), 115.1ms
# Speed: 1.3ms preprocess, 115.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000046.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000047.jpg: 384x640 (no detections), 57.1ms
# Speed: 1.1ms preprocess, 57.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000047.jpg: 384x640 1 full, 51.6ms
# Speed: 1.3ms preprocess, 51.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000047.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000048.jpg: 384x640 1 open, 61.2ms
# Speed: 1.1ms preprocess, 61.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000048.jpg: 384x640 1 full, 59.0ms
# Speed: 1.1ms preprocess, 59.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000048.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000049.jpg: 384x640 (no detections), 77.0ms
# Speed: 1.3ms preprocess, 77.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000049.jpg: 384x640 (no detections), 53.5ms
# Speed: 1.2ms preprocess, 53.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000049.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000050.jpg: 384x640 (no detections), 49.1ms
# Speed: 1.2ms preprocess, 49.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000050.jpg: 384x640 (no detections), 57.1ms
# Speed: 1.3ms preprocess, 57.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000050.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000051.jpg: 384x640 (no detections), 75.0ms
# Speed: 1.2ms preprocess, 75.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000051.jpg: 384x640 (no detections), 65.3ms
# Speed: 1.2ms preprocess, 65.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000051.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000052.jpg: 384x640 (no detections), 67.8ms
# Speed: 1.2ms preprocess, 67.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000052.jpg: 384x640 1 full, 54.2ms
# Speed: 1.1ms preprocess, 54.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000052.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000053.jpg: 384x640 1 open, 62.8ms
# Speed: 1.5ms preprocess, 62.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000053.jpg: 384x640 (no detections), 55.1ms
# Speed: 1.1ms preprocess, 55.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000053.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000054.jpg: 384x640 (no detections), 66.4ms
# Speed: 1.3ms preprocess, 66.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000054.jpg: 384x640 (no detections), 53.6ms
# Speed: 1.4ms preprocess, 53.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000054.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000055.jpg: 384x640 (no detections), 77.3ms
# Speed: 1.8ms preprocess, 77.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000055.jpg: 384x640 (no detections), 75.0ms
# Speed: 1.2ms preprocess, 75.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000055.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000056.jpg: 384x640 (no detections), 55.8ms
# Speed: 1.2ms preprocess, 55.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000056.jpg: 384x640 (no detections), 51.4ms
# Speed: 1.2ms preprocess, 51.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000056.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000057.jpg: 384x640 (no detections), 90.8ms
# Speed: 1.2ms preprocess, 90.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000057.jpg: 384x640 (no detections), 119.5ms
# Speed: 1.2ms preprocess, 119.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000057.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000058.jpg: 384x640 (no detections), 69.5ms
# Speed: 2.1ms preprocess, 69.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000058.jpg: 384x640 1 full, 57.4ms
# Speed: 1.2ms preprocess, 57.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000058.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000059.jpg: 384x640 (no detections), 53.7ms
# Speed: 1.1ms preprocess, 53.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000059.jpg: 384x640 (no detections), 53.3ms
# Speed: 1.2ms preprocess, 53.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000059.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000060.jpg: 384x640 (no detections), 59.3ms
# Speed: 1.2ms preprocess, 59.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000060.jpg: 384x640 (no detections), 57.6ms
# Speed: 1.2ms preprocess, 57.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000060.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000061.jpg: 384x640 (no detections), 56.9ms
# Speed: 1.2ms preprocess, 56.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000061.jpg: 384x640 1 full, 52.4ms
# Speed: 1.1ms preprocess, 52.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000061.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000062.jpg: 384x640 (no detections), 57.4ms
# Speed: 1.4ms preprocess, 57.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000062.jpg: 384x640 (no detections), 57.4ms
# Speed: 1.3ms preprocess, 57.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000062.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000063.jpg: 384x640 1 open, 50.7ms
# Speed: 1.3ms preprocess, 50.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000063.jpg: 384x640 1 full, 50.5ms
# Speed: 1.2ms preprocess, 50.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000063.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000064.jpg: 384x640 2 opens, 64.8ms
# Speed: 1.3ms preprocess, 64.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000064.jpg: 384x640 (no detections), 55.8ms
# Speed: 1.2ms preprocess, 55.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000064.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000065.jpg: 384x640 (no detections), 63.4ms
# Speed: 1.9ms preprocess, 63.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000065.jpg: 384x640 1 full, 51.5ms
# Speed: 1.3ms preprocess, 51.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000065.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000066.jpg: 384x640 1 open, 59.6ms
# Speed: 1.2ms preprocess, 59.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000066.jpg: 384x640 (no detections), 52.9ms
# Speed: 1.4ms preprocess, 52.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000066.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000067.jpg: 384x640 1 open, 1 close, 52.8ms
# Speed: 1.2ms preprocess, 52.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000067.jpg: 384x640 1 full, 58.4ms
# Speed: 1.1ms preprocess, 58.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000067.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000068.jpg: 384x640 2 opens, 115.3ms
# Speed: 1.3ms preprocess, 115.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000068.jpg: 384x640 1 empty, 1 full, 55.9ms
# Speed: 1.2ms preprocess, 55.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000068.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000069.jpg: 384x640 3 closes, 75.4ms
# Speed: 1.1ms preprocess, 75.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000069.jpg: 384x640 1 empty, 1 full, 58.3ms
# Speed: 1.2ms preprocess, 58.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000069.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000070.jpg: 384x640 3 closes, 56.1ms
# Speed: 1.1ms preprocess, 56.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000070.jpg: 384x640 1 empty, 1 full, 59.9ms
# Speed: 1.2ms preprocess, 59.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000070.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000071.jpg: 384x640 3 closes, 59.5ms
# Speed: 1.1ms preprocess, 59.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000071.jpg: 384x640 1 empty, 65.1ms
# Speed: 1.2ms preprocess, 65.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000071.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000072.jpg: 384x640 3 closes, 76.3ms
# Speed: 2.9ms preprocess, 76.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000072.jpg: 384x640 1 empty, 85.4ms
# Speed: 2.3ms preprocess, 85.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000072.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000073.jpg: 384x640 3 closes, 66.6ms
# Speed: 1.2ms preprocess, 66.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000073.jpg: 384x640 1 empty, 104.1ms
# Speed: 1.2ms preprocess, 104.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000073.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000074.jpg: 384x640 3 closes, 70.9ms
# Speed: 1.1ms preprocess, 70.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000074.jpg: 384x640 1 empty, 70.5ms
# Speed: 1.9ms preprocess, 70.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000074.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000075.jpg: 384x640 2 closes, 58.7ms
# Speed: 1.6ms preprocess, 58.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000075.jpg: 384x640 1 empty, 55.4ms
# Speed: 1.5ms preprocess, 55.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000075.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000076.jpg: 384x640 2 closes, 58.7ms
# Speed: 1.2ms preprocess, 58.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000076.jpg: 384x640 2 emptys, 57.2ms
# Speed: 1.2ms preprocess, 57.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000076.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000077.jpg: 384x640 3 closes, 62.7ms
# Speed: 1.3ms preprocess, 62.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000077.jpg: 384x640 2 emptys, 114.3ms
# Speed: 1.2ms preprocess, 114.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000077.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000078.jpg: 384x640 2 closes, 64.7ms
# Speed: 1.2ms preprocess, 64.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000078.jpg: 384x640 1 empty, 1 full, 59.9ms
# Speed: 1.1ms preprocess, 59.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000078.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000079.jpg: 384x640 3 closes, 68.3ms
# Speed: 1.1ms preprocess, 68.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000079.jpg: 384x640 2 emptys, 50.5ms
# Speed: 1.2ms preprocess, 50.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000079.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000080.jpg: 384x640 3 closes, 62.2ms
# Speed: 1.3ms preprocess, 62.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000080.jpg: 384x640 2 emptys, 57.8ms
# Speed: 1.2ms preprocess, 57.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000080.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000081.jpg: 384x640 3 closes, 54.4ms
# Speed: 1.1ms preprocess, 54.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000081.jpg: 384x640 1 empty, 51.4ms
# Speed: 1.9ms preprocess, 51.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000081.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000082.jpg: 384x640 2 closes, 57.7ms
# Speed: 1.3ms preprocess, 57.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000082.jpg: 384x640 1 empty, 51.2ms
# Speed: 1.1ms preprocess, 51.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000082.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000083.jpg: 384x640 1 open, 1 close, 54.9ms
# Speed: 1.3ms preprocess, 54.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000083.jpg: 384x640 2 fulls, 50.8ms
# Speed: 1.1ms preprocess, 50.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000083.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000084.jpg: 384x640 2 opens, 60.7ms
# Speed: 1.6ms preprocess, 60.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000084.jpg: 384x640 1 full, 54.7ms
# Speed: 1.2ms preprocess, 54.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000084.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000085.jpg: 384x640 1 open, 50.6ms
# Speed: 1.3ms preprocess, 50.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000085.jpg: 384x640 1 full, 51.2ms
# Speed: 1.2ms preprocess, 51.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000085.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000086.jpg: 384x640 1 open, 1 close, 57.0ms
# Speed: 1.7ms preprocess, 57.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000086.jpg: 384x640 1 full, 51.2ms
# Speed: 1.3ms preprocess, 51.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000086.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000087.jpg: 384x640 2 opens, 110.8ms
# Speed: 1.5ms preprocess, 110.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000087.jpg: 384x640 2 fulls, 75.1ms
# Speed: 1.1ms preprocess, 75.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000087.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000088.jpg: 384x640 2 opens, 52.6ms
# Speed: 1.2ms preprocess, 52.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000088.jpg: 384x640 1 full, 49.9ms
# Speed: 1.1ms preprocess, 49.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000088.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000089.jpg: 384x640 2 opens, 1 close, 73.9ms
# Speed: 1.4ms preprocess, 73.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000089.jpg: 384x640 2 emptys, 68.1ms
# Speed: 1.2ms preprocess, 68.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000089.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000090.jpg: 384x640 2 opens, 1 close, 61.4ms
# Speed: 1.1ms preprocess, 61.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000090.jpg: 384x640 2 emptys, 68.7ms
# Speed: 1.4ms preprocess, 68.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000090.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000091.jpg: 384x640 3 opens, 1 close, 65.0ms
# Speed: 1.3ms preprocess, 65.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000091.jpg: 384x640 2 emptys, 59.7ms
# Speed: 1.2ms preprocess, 59.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000091.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000092.jpg: 384x640 2 opens, 1 close, 63.2ms
# Speed: 1.5ms preprocess, 63.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000092.jpg: 384x640 2 emptys, 52.2ms
# Speed: 1.1ms preprocess, 52.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000092.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000093.jpg: 384x640 3 opens, 63.4ms
# Speed: 1.2ms preprocess, 63.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000093.jpg: 384x640 2 emptys, 62.8ms
# Speed: 1.2ms preprocess, 62.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000093.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000094.jpg: 384x640 3 opens, 1 close, 57.7ms
# Speed: 1.2ms preprocess, 57.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000094.jpg: 384x640 2 emptys, 57.5ms
# Speed: 1.1ms preprocess, 57.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000094.jpg
#
# ...
# Speed: 1.8ms preprocess, 95.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000420.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000421.jpg: 384x640 (no detections), 61.8ms
# Speed: 1.4ms preprocess, 61.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000421.jpg: 384x640 (no detections), 58.6ms
# Speed: 1.2ms preprocess, 58.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000421.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000422.jpg: 384x640 (no detections), 101.4ms
# Speed: 1.6ms preprocess, 101.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000422.jpg: 384x640 (no detections), 57.2ms
# Speed: 1.2ms preprocess, 57.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000422.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000423.jpg: 384x640 (no detections), 70.2ms
# Speed: 1.6ms preprocess, 70.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000423.jpg: 384x640 1 full, 82.2ms
# Speed: 1.3ms preprocess, 82.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000423.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000424.jpg: 384x640 (no detections), 66.5ms
# Speed: 1.2ms preprocess, 66.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000424.jpg: 384x640 (no detections), 58.3ms
# Speed: 1.1ms preprocess, 58.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000424.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000425.jpg: 384x640 (no detections), 62.7ms
# Speed: 1.4ms preprocess, 62.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000425.jpg: 384x640 1 full, 61.0ms
# Speed: 1.4ms preprocess, 61.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000425.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000426.jpg: 384x640 1 open, 64.2ms
# Speed: 1.3ms preprocess, 64.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000426.jpg: 384x640 1 full, 81.6ms
# Speed: 1.2ms preprocess, 81.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000426.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000427.jpg: 384x640 2 opens, 110.8ms
# Speed: 2.1ms preprocess, 110.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000427.jpg: 384x640 1 full, 63.0ms
# Speed: 1.2ms preprocess, 63.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000427.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000428.jpg: 384x640 1 open, 76.3ms
# Speed: 1.9ms preprocess, 76.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000428.jpg: 384x640 1 full, 57.7ms
# Speed: 2.1ms preprocess, 57.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000428.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000429.jpg: 384x640 (no detections), 76.9ms
# Speed: 2.1ms preprocess, 76.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000429.jpg: 384x640 (no detections), 57.6ms
# Speed: 1.7ms preprocess, 57.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000429.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000430.jpg: 384x640 (no detections), 59.0ms
# Speed: 2.2ms preprocess, 59.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000430.jpg: 384x640 (no detections), 57.6ms
# Speed: 1.9ms preprocess, 57.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000430.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000431.jpg: 384x640 (no detections), 60.3ms
# Speed: 1.4ms preprocess, 60.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000431.jpg: 384x640 (no detections), 58.3ms
# Speed: 1.2ms preprocess, 58.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000431.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000432.jpg: 384x640 (no detections), 72.7ms
# Speed: 2.1ms preprocess, 72.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000432.jpg: 384x640 1 full, 56.2ms
# Speed: 1.1ms preprocess, 56.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000432.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000433.jpg: 384x640 (no detections), 73.9ms
# Speed: 1.4ms preprocess, 73.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000433.jpg: 384x640 (no detections), 65.0ms
# Speed: 1.3ms preprocess, 65.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000433.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000434.jpg: 384x640 (no detections), 57.8ms
# Speed: 1.3ms preprocess, 57.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000434.jpg: 384x640 (no detections), 58.3ms
# Speed: 1.6ms preprocess, 58.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000434.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000435.jpg: 384x640 (no detections), 64.8ms
# Speed: 2.2ms preprocess, 64.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000435.jpg: 384x640 (no detections), 56.2ms
# Speed: 2.0ms preprocess, 56.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000435.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000436.jpg: 384x640 (no detections), 65.2ms
# Speed: 2.2ms preprocess, 65.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000436.jpg: 384x640 (no detections), 57.6ms
# Speed: 1.6ms preprocess, 57.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000436.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000437.jpg: 384x640 (no detections), 90.7ms
# Speed: 1.8ms preprocess, 90.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000437.jpg: 384x640 1 full, 73.0ms
# Speed: 1.7ms preprocess, 73.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000437.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000438.jpg: 384x640 (no detections), 61.7ms
# Speed: 2.7ms preprocess, 61.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000438.jpg: 384x640 (no detections), 57.8ms
# Speed: 1.7ms preprocess, 57.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000438.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000439.jpg: 384x640 (no detections), 60.8ms
# Speed: 2.5ms preprocess, 60.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000439.jpg: 384x640 (no detections), 69.8ms
# Speed: 1.7ms preprocess, 69.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000439.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000440.jpg: 384x640 (no detections), 75.7ms
# Speed: 2.1ms preprocess, 75.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000440.jpg: 384x640 (no detections), 56.9ms
# Speed: 1.8ms preprocess, 56.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000440.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000441.jpg: 384x640 (no detections), 61.0ms
# Speed: 2.2ms preprocess, 61.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000441.jpg: 384x640 (no detections), 59.2ms
# Speed: 1.8ms preprocess, 59.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000441.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000442.jpg: 384x640 (no detections), 85.8ms
# Speed: 2.2ms preprocess, 85.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000442.jpg: 384x640 (no detections), 77.1ms
# Speed: 1.8ms preprocess, 77.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000442.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000443.jpg: 384x640 (no detections), 63.7ms
# Speed: 2.0ms preprocess, 63.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000443.jpg: 384x640 (no detections), 63.6ms
# Speed: 1.6ms preprocess, 63.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000443.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000444.jpg: 384x640 (no detections), 60.5ms
# Speed: 1.7ms preprocess, 60.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000444.jpg: 384x640 (no detections), 63.6ms
# Speed: 1.3ms preprocess, 63.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000444.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000445.jpg: 384x640 (no detections), 74.7ms
# Speed: 2.2ms preprocess, 74.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000445.jpg: 384x640 (no detections), 61.4ms
# Speed: 2.0ms preprocess, 61.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000445.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000446.jpg: 384x640 (no detections), 59.1ms
# Speed: 1.8ms preprocess, 59.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000446.jpg: 384x640 (no detections), 60.2ms
# Speed: 1.3ms preprocess, 60.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000446.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000447.jpg: 384x640 (no detections), 83.2ms
# Speed: 2.3ms preprocess, 83.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000447.jpg: 384x640 (no detections), 76.0ms
# Speed: 1.1ms preprocess, 76.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000447.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000448.jpg: 384x640 (no detections), 67.3ms
# Speed: 1.3ms preprocess, 67.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000448.jpg: 384x640 (no detections), 77.0ms
# Speed: 2.5ms preprocess, 77.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000448.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000449.jpg: 384x640 (no detections), 67.2ms
# Speed: 1.3ms preprocess, 67.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000449.jpg: 384x640 1 full, 67.2ms
# Speed: 1.5ms preprocess, 67.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000449.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000450.jpg: 384x640 (no detections), 95.4ms
# Speed: 1.6ms preprocess, 95.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000450.jpg: 384x640 (no detections), 61.3ms
# Speed: 1.2ms preprocess, 61.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000450.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000451.jpg: 384x640 (no detections), 72.4ms
# Speed: 2.9ms preprocess, 72.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_normal_new_003\frame_000451.jpg: 384x640 (no detections), 59.2ms
# Speed: 1.8ms preprocess, 59.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000451.jpg

# %%
# ===== 샘플 이미지 목록 =====
sample_imgs = []
for ext in ("*.jpg", "*.png"):
    sample_imgs.extend(glob.glob(os.path.join(IMG_DIR3, ext)))
sample_imgs = natsorted(sample_imgs)

print(f"[INFO] Found {len(sample_imgs)} images.")

# 클래스 이름 (학습할 때 쓴 순서와 맞춰야 함)
OC_NAMES = ["open", "close"]   # open/close 모델
FE_NAMES = ["empty", "full"]   # full/empty 모델

for img_path in sample_imgs:
    # 이미지 로드 (BGR -> RGB)
    img_bgr = cv2.imread(img_path)
    if img_bgr is None:
        print(f"[WARN] 이미지 로드 실패: {img_path}")
        continue
    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

    # -------- 1) 두 모델로 각각 추론 --------
    res_oc = model_oc(img_path, imgsz=640, conf=0.25)[0]
    res_fe = model_fe(img_path, imgsz=640, conf=0.25)[0]

    # 시각화용 복사본
    vis = img_rgb.copy()

    # -------- 2) open/close 박스 (얇은 초록색) --------
    if res_oc.boxes is not None and len(res_oc.boxes) > 0:
        for box, cls, conf in zip(res_oc.boxes.xyxy, res_oc.boxes.cls, res_oc.boxes.conf):
            x1, y1, x2, y2 = box.tolist()
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)

            cls_idx = int(cls.item())
            label = f"OC:{OC_NAMES[cls_idx]} {conf.item():.2f}"

            # 얇은 초록색 박스
            cv2.rectangle(
                vis,
                (x1, y1),
                (x2, y2),
                color=(0, 255, 0),   # BGR in cv2, but vis is RGB라 상관 없음 (색만 맞추면 됨)
                thickness=2
            )
            # 라벨 텍스트 (박스 위에)
            cv2.putText(
                vis,
                label,
                (x1, max(y1 - 5, 0)),
                cv2.FONT_HERSHEY_SIMPLEX,
                0.6,
                (0, 255, 0),
                2,
                cv2.LINE_AA
            )

    # -------- 3) full/empty 박스 (두꺼운 빨간색) --------
    if res_fe.boxes is not None and len(res_fe.boxes) > 0:
        for box, cls, conf in zip(res_fe.boxes.xyxy, res_fe.boxes.cls, res_fe.boxes.conf):
            x1, y1, x2, y2 = box.tolist()
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)

            cls_idx = int(cls.item())
            label = f"FE:{FE_NAMES[cls_idx]} {conf.item():.2f}"

            # 더 두꺼운 빨간색 박스
            cv2.rectangle(
                vis,
                (x1, y1),
                (x2, y2),
                color=(255, 0, 0),   # BGR
                thickness=4
            )
            # 라벨 텍스트 (박스 아래쪽에)
            cv2.putText(
                vis,
                label,
                (x1, min(y2 + 20, vis.shape[0] - 5)),
                cv2.FONT_HERSHEY_SIMPLEX,
                0.6,
                (255, 0, 0),
                2,
                cv2.LINE_AA
            )

    # -------- 4) 시각화 결과 저장 + 필요 시 화면에도 표시 --------
    out_name = os.path.basename(img_path)
    out_path = os.path.join(OUT_OC_FE_DIR, out_name)

    # vis는 RGB라 BGR로 변환 후 저장
    vis_bgr = cv2.cvtColor(vis, cv2.COLOR_RGB2BGR)
    cv2.imwrite(out_path, vis_bgr)
    print(f"[INFO] Saved vis image: {out_path}")

    # 필요하면 바로 plt로 보여주기
    # plt.figure(figsize=(6, 6))
    # plt.title(os.path.basename(img_path))
    # plt.imshow(vis)
    # plt.axis('off')
    # plt.show()
# Out:
# [INFO] Found 216 images.
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000000.jpg: 384x640 (no detections), 121.5ms
# Speed: 1.8ms preprocess, 121.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000000.jpg: 384x640 (no detections), 70.7ms
# Speed: 1.2ms preprocess, 70.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000000.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000001.jpg: 384x640 (no detections), 78.7ms
# Speed: 1.8ms preprocess, 78.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000001.jpg: 384x640 (no detections), 84.3ms
# Speed: 2.2ms preprocess, 84.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000001.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000002.jpg: 384x640 (no detections), 88.7ms
# Speed: 1.6ms preprocess, 88.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000002.jpg: 384x640 (no detections), 85.2ms
# Speed: 1.3ms preprocess, 85.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000002.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000003.jpg: 384x640 (no detections), 74.4ms
# Speed: 1.4ms preprocess, 74.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000003.jpg: 384x640 (no detections), 73.0ms
# Speed: 1.2ms preprocess, 73.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000003.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000004.jpg: 384x640 (no detections), 114.8ms
# Speed: 1.2ms preprocess, 114.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000004.jpg: 384x640 (no detections), 62.2ms
# Speed: 1.5ms preprocess, 62.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000004.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000005.jpg: 384x640 (no detections), 75.6ms
# Speed: 1.2ms preprocess, 75.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000005.jpg: 384x640 (no detections), 68.2ms
# Speed: 1.1ms preprocess, 68.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000005.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000006.jpg: 384x640 (no detections), 78.6ms
# Speed: 1.5ms preprocess, 78.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000006.jpg: 384x640 (no detections), 67.9ms
# Speed: 1.1ms preprocess, 67.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000006.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000007.jpg: 384x640 (no detections), 82.0ms
# Speed: 1.2ms preprocess, 82.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000007.jpg: 384x640 (no detections), 69.2ms
# Speed: 1.1ms preprocess, 69.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000007.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000008.jpg: 384x640 (no detections), 72.2ms
# Speed: 1.2ms preprocess, 72.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000008.jpg: 384x640 (no detections), 65.2ms
# Speed: 1.8ms preprocess, 65.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000008.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000009.jpg: 384x640 (no detections), 77.9ms
# Speed: 1.7ms preprocess, 77.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000009.jpg: 384x640 (no detections), 61.7ms
# Speed: 1.3ms preprocess, 61.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000009.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000010.jpg: 384x640 (no detections), 75.0ms
# Speed: 1.3ms preprocess, 75.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000010.jpg: 384x640 (no detections), 64.2ms
# Speed: 1.1ms preprocess, 64.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000010.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000011.jpg: 384x640 (no detections), 92.0ms
# Speed: 1.4ms preprocess, 92.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000011.jpg: 384x640 (no detections), 63.9ms
# Speed: 1.2ms preprocess, 63.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000011.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000012.jpg: 384x640 (no detections), 57.6ms
# Speed: 1.2ms preprocess, 57.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000012.jpg: 384x640 (no detections), 54.1ms
# Speed: 1.5ms preprocess, 54.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000012.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000013.jpg: 384x640 (no detections), 62.0ms
# Speed: 1.6ms preprocess, 62.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000013.jpg: 384x640 (no detections), 57.4ms
# Speed: 1.3ms preprocess, 57.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000013.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000014.jpg: 384x640 (no detections), 89.8ms
# Speed: 1.8ms preprocess, 89.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000014.jpg: 384x640 (no detections), 71.2ms
# Speed: 1.2ms preprocess, 71.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000014.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000015.jpg: 384x640 (no detections), 70.2ms
# Speed: 1.2ms preprocess, 70.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000015.jpg: 384x640 (no detections), 71.0ms
# Speed: 1.1ms preprocess, 71.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000015.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000016.jpg: 384x640 (no detections), 61.0ms
# Speed: 1.3ms preprocess, 61.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000016.jpg: 384x640 (no detections), 60.1ms
# Speed: 1.2ms preprocess, 60.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000016.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000017.jpg: 384x640 (no detections), 70.1ms
# Speed: 1.1ms preprocess, 70.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000017.jpg: 384x640 (no detections), 60.1ms
# Speed: 1.1ms preprocess, 60.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000017.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000018.jpg: 384x640 (no detections), 68.7ms
# Speed: 1.1ms preprocess, 68.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000018.jpg: 384x640 (no detections), 58.4ms
# Speed: 1.2ms preprocess, 58.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000018.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000019.jpg: 384x640 (no detections), 65.4ms
# Speed: 1.2ms preprocess, 65.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000019.jpg: 384x640 (no detections), 65.9ms
# Speed: 1.7ms preprocess, 65.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000019.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000020.jpg: 384x640 (no detections), 75.4ms
# Speed: 1.4ms preprocess, 75.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000020.jpg: 384x640 (no detections), 60.3ms
# Speed: 1.3ms preprocess, 60.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000020.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000021.jpg: 384x640 (no detections), 70.8ms
# Speed: 1.3ms preprocess, 70.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000021.jpg: 384x640 (no detections), 59.5ms
# Speed: 1.2ms preprocess, 59.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000021.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000022.jpg: 384x640 (no detections), 68.6ms
# Speed: 1.8ms preprocess, 68.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000022.jpg: 384x640 (no detections), 56.2ms
# Speed: 1.4ms preprocess, 56.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000022.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000023.jpg: 384x640 (no detections), 64.1ms
# Speed: 1.2ms preprocess, 64.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000023.jpg: 384x640 (no detections), 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000023.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000024.jpg: 384x640 (no detections), 88.8ms
# Speed: 2.8ms preprocess, 88.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000024.jpg: 384x640 (no detections), 72.3ms
# Speed: 2.0ms preprocess, 72.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000024.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000025.jpg: 384x640 (no detections), 72.0ms
# Speed: 2.7ms preprocess, 72.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000025.jpg: 384x640 (no detections), 126.5ms
# Speed: 1.8ms preprocess, 126.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000025.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000026.jpg: 384x640 (no detections), 67.6ms
# Speed: 1.8ms preprocess, 67.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000026.jpg: 384x640 (no detections), 112.8ms
# Speed: 2.5ms preprocess, 112.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000026.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000027.jpg: 384x640 (no detections), 84.7ms
# Speed: 1.8ms preprocess, 84.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000027.jpg: 384x640 (no detections), 135.3ms
# Speed: 1.4ms preprocess, 135.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000027.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000028.jpg: 384x640 (no detections), 92.1ms
# Speed: 2.4ms preprocess, 92.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000028.jpg: 384x640 (no detections), 130.7ms
# Speed: 3.4ms preprocess, 130.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000028.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000029.jpg: 384x640 (no detections), 92.3ms
# Speed: 2.1ms preprocess, 92.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000029.jpg: 384x640 (no detections), 80.3ms
# Speed: 1.3ms preprocess, 80.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000029.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000030.jpg: 384x640 (no detections), 105.0ms
# Speed: 5.2ms preprocess, 105.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000030.jpg: 384x640 (no detections), 88.9ms
# Speed: 1.7ms preprocess, 88.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000030.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000031.jpg: 384x640 (no detections), 85.2ms
# Speed: 2.5ms preprocess, 85.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000031.jpg: 384x640 (no detections), 86.3ms
# Speed: 1.3ms preprocess, 86.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000031.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000032.jpg: 384x640 1 open, 119.0ms
# Speed: 1.4ms preprocess, 119.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000032.jpg: 384x640 (no detections), 104.3ms
# Speed: 1.3ms preprocess, 104.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000032.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000033.jpg: 384x640 (no detections), 77.2ms
# Speed: 2.5ms preprocess, 77.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000033.jpg: 384x640 1 full, 68.6ms
# Speed: 2.1ms preprocess, 68.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000033.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000034.jpg: 384x640 (no detections), 80.1ms
# Speed: 1.6ms preprocess, 80.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000034.jpg: 384x640 (no detections), 70.8ms
# Speed: 1.4ms preprocess, 70.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000034.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000035.jpg: 384x640 (no detections), 84.6ms
# Speed: 1.4ms preprocess, 84.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000035.jpg: 384x640 (no detections), 75.8ms
# Speed: 1.3ms preprocess, 75.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000035.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000036.jpg: 384x640 (no detections), 140.8ms
# Speed: 1.4ms preprocess, 140.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000036.jpg: 384x640 (no detections), 83.5ms
# Speed: 3.4ms preprocess, 83.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000036.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000037.jpg: 384x640 (no detections), 90.0ms
# Speed: 1.3ms preprocess, 90.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000037.jpg: 384x640 (no detections), 79.2ms
# Speed: 1.2ms preprocess, 79.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000037.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000038.jpg: 384x640 (no detections), 179.5ms
# Speed: 1.6ms preprocess, 179.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000038.jpg: 384x640 (no detections), 90.1ms
# Speed: 1.7ms preprocess, 90.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000038.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000039.jpg: 384x640 (no detections), 64.2ms
# Speed: 2.4ms preprocess, 64.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000039.jpg: 384x640 (no detections), 101.7ms
# Speed: 1.8ms preprocess, 101.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000039.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000040.jpg: 384x640 (no detections), 62.0ms
# Speed: 1.6ms preprocess, 62.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000040.jpg: 384x640 (no detections), 116.2ms
# Speed: 2.6ms preprocess, 116.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000040.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000041.jpg: 384x640 (no detections), 73.5ms
# Speed: 2.0ms preprocess, 73.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000041.jpg: 384x640 (no detections), 65.3ms
# Speed: 2.3ms preprocess, 65.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000041.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000042.jpg: 384x640 (no detections), 66.6ms
# Speed: 2.2ms preprocess, 66.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000042.jpg: 384x640 (no detections), 63.1ms
# Speed: 1.8ms preprocess, 63.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000042.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000043.jpg: 384x640 (no detections), 68.0ms
# Speed: 1.6ms preprocess, 68.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000043.jpg: 384x640 (no detections), 76.2ms
# Speed: 2.1ms preprocess, 76.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000043.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000044.jpg: 384x640 1 open, 61.7ms
# Speed: 2.2ms preprocess, 61.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000044.jpg: 384x640 (no detections), 60.8ms
# Speed: 1.8ms preprocess, 60.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000044.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000045.jpg: 384x640 (no detections), 61.5ms
# Speed: 1.6ms preprocess, 61.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000045.jpg: 384x640 (no detections), 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000045.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000046.jpg: 384x640 (no detections), 59.0ms
# Speed: 1.8ms preprocess, 59.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000046.jpg: 384x640 (no detections), 59.0ms
# Speed: 1.7ms preprocess, 59.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000046.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000047.jpg: 384x640 (no detections), 60.2ms
# Speed: 2.2ms preprocess, 60.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000047.jpg: 384x640 (no detections), 98.6ms
# Speed: 13.8ms preprocess, 98.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000047.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000048.jpg: 384x640 (no detections), 73.1ms
# Speed: 1.4ms preprocess, 73.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000048.jpg: 384x640 (no detections), 62.9ms
# Speed: 1.2ms preprocess, 62.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000048.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000049.jpg: 384x640 (no detections), 106.6ms
# Speed: 2.3ms preprocess, 106.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000049.jpg: 384x640 (no detections), 94.1ms
# Speed: 2.3ms preprocess, 94.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000049.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000050.jpg: 384x640 (no detections), 180.6ms
# Speed: 3.6ms preprocess, 180.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000050.jpg: 384x640 1 full, 187.1ms
# Speed: 2.0ms preprocess, 187.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000050.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000051.jpg: 384x640 (no detections), 107.6ms
# Speed: 1.8ms preprocess, 107.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000051.jpg: 384x640 (no detections), 109.4ms
# Speed: 6.4ms preprocess, 109.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000051.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000052.jpg: 384x640 (no detections), 152.4ms
# Speed: 2.6ms preprocess, 152.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000052.jpg: 384x640 (no detections), 130.2ms
# Speed: 2.5ms preprocess, 130.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000052.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000053.jpg: 384x640 1 open, 116.9ms
# Speed: 2.5ms preprocess, 116.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000053.jpg: 384x640 (no detections), 72.8ms
# Speed: 2.1ms preprocess, 72.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000053.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000054.jpg: 384x640 1 open, 89.4ms
# Speed: 4.1ms preprocess, 89.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000054.jpg: 384x640 (no detections), 93.8ms
# Speed: 2.0ms preprocess, 93.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000054.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000055.jpg: 384x640 (no detections), 107.8ms
# Speed: 2.3ms preprocess, 107.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000055.jpg: 384x640 (no detections), 76.4ms
# Speed: 3.1ms preprocess, 76.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000055.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000056.jpg: 384x640 (no detections), 71.6ms
# Speed: 1.8ms preprocess, 71.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000056.jpg: 384x640 (no detections), 72.5ms
# Speed: 1.7ms preprocess, 72.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000056.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000057.jpg: 384x640 (no detections), 72.0ms
# Speed: 2.0ms preprocess, 72.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000057.jpg: 384x640 (no detections), 70.4ms
# Speed: 2.2ms preprocess, 70.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000057.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000058.jpg: 384x640 (no detections), 85.4ms
# Speed: 18.7ms preprocess, 85.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000058.jpg: 384x640 (no detections), 71.1ms
# Speed: 1.8ms preprocess, 71.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000058.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000059.jpg: 384x640 (no detections), 69.9ms
# Speed: 1.7ms preprocess, 69.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000059.jpg: 384x640 (no detections), 76.2ms
# Speed: 1.9ms preprocess, 76.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000059.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000060.jpg: 384x640 (no detections), 93.8ms
# Speed: 1.8ms preprocess, 93.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000060.jpg: 384x640 (no detections), 72.4ms
# Speed: 2.2ms preprocess, 72.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000060.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000061.jpg: 384x640 (no detections), 108.8ms
# Speed: 2.3ms preprocess, 108.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000061.jpg: 384x640 1 full, 68.9ms
# Speed: 1.5ms preprocess, 68.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000061.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000062.jpg: 384x640 (no detections), 138.3ms
# Speed: 1.6ms preprocess, 138.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000062.jpg: 384x640 1 full, 73.8ms
# Speed: 2.4ms preprocess, 73.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000062.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000063.jpg: 384x640 (no detections), 87.8ms
# Speed: 2.4ms preprocess, 87.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000063.jpg: 384x640 1 full, 107.2ms
# Speed: 1.5ms preprocess, 107.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000063.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000064.jpg: 384x640 (no detections), 119.6ms
# Speed: 1.4ms preprocess, 119.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000064.jpg: 384x640 2 fulls, 96.0ms
# Speed: 2.2ms preprocess, 96.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000064.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000065.jpg: 384x640 3 opens, 132.3ms
# Speed: 1.7ms preprocess, 132.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000065.jpg: 384x640 1 full, 74.3ms
# Speed: 1.4ms preprocess, 74.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000065.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000066.jpg: 384x640 1 open, 130.1ms
# Speed: 4.3ms preprocess, 130.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000066.jpg: 384x640 1 full, 107.8ms
# Speed: 1.3ms preprocess, 107.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000066.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000067.jpg: 384x640 1 open, 63.7ms
# Speed: 2.9ms preprocess, 63.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000067.jpg: 384x640 1 full, 83.7ms
# Speed: 1.9ms preprocess, 83.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000067.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000068.jpg: 384x640 1 open, 87.3ms
# Speed: 2.6ms preprocess, 87.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000068.jpg: 384x640 1 full, 60.2ms
# Speed: 1.9ms preprocess, 60.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000068.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000069.jpg: 384x640 1 open, 72.1ms
# Speed: 2.4ms preprocess, 72.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000069.jpg: 384x640 1 full, 57.9ms
# Speed: 1.1ms preprocess, 57.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000069.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000070.jpg: 384x640 1 open, 70.5ms
# Speed: 1.3ms preprocess, 70.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000070.jpg: 384x640 1 full, 60.6ms
# Speed: 1.1ms preprocess, 60.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000070.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000071.jpg: 384x640 1 open, 89.4ms
# Speed: 1.2ms preprocess, 89.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000071.jpg: 384x640 1 full, 68.2ms
# Speed: 1.4ms preprocess, 68.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000071.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000072.jpg: 384x640 1 open, 65.7ms
# Speed: 1.3ms preprocess, 65.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000072.jpg: 384x640 1 full, 65.3ms
# Speed: 1.3ms preprocess, 65.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000072.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000073.jpg: 384x640 1 open, 93.8ms
# Speed: 2.6ms preprocess, 93.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000073.jpg: 384x640 1 full, 99.5ms
# Speed: 1.2ms preprocess, 99.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000073.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000074.jpg: 384x640 1 open, 65.4ms
# Speed: 1.3ms preprocess, 65.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000074.jpg: 384x640 1 full, 68.9ms
# Speed: 1.1ms preprocess, 68.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000074.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000075.jpg: 384x640 1 open, 68.4ms
# Speed: 1.2ms preprocess, 68.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000075.jpg: 384x640 2 fulls, 73.0ms
# Speed: 1.2ms preprocess, 73.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000075.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000076.jpg: 384x640 2 opens, 75.3ms
# Speed: 1.2ms preprocess, 75.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000076.jpg: 384x640 2 fulls, 76.4ms
# Speed: 1.9ms preprocess, 76.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000076.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000077.jpg: 384x640 2 opens, 67.3ms
# Speed: 1.3ms preprocess, 67.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000077.jpg: 384x640 2 fulls, 60.1ms
# Speed: 1.1ms preprocess, 60.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000077.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000078.jpg: 384x640 2 opens, 146.5ms
# Speed: 1.5ms preprocess, 146.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000078.jpg: 384x640 2 fulls, 61.9ms
# Speed: 2.2ms preprocess, 61.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000078.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000079.jpg: 384x640 2 opens, 60.8ms
# Speed: 1.4ms preprocess, 60.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000079.jpg: 384x640 2 fulls, 59.9ms
# Speed: 1.1ms preprocess, 59.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000079.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000080.jpg: 384x640 2 opens, 63.3ms
# Speed: 1.2ms preprocess, 63.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000080.jpg: 384x640 2 fulls, 66.3ms
# Speed: 1.1ms preprocess, 66.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000080.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000081.jpg: 384x640 2 opens, 70.6ms
# Speed: 1.6ms preprocess, 70.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000081.jpg: 384x640 2 fulls, 59.7ms
# Speed: 1.2ms preprocess, 59.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000081.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000082.jpg: 384x640 2 opens, 63.0ms
# Speed: 2.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000082.jpg: 384x640 2 fulls, 68.2ms
# Speed: 1.2ms preprocess, 68.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000082.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000083.jpg: 384x640 2 opens, 78.2ms
# Speed: 1.5ms preprocess, 78.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000083.jpg: 384x640 2 fulls, 83.8ms
# Speed: 1.5ms preprocess, 83.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000083.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000084.jpg: 384x640 3 opens, 100.0ms
# Speed: 1.3ms preprocess, 100.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000084.jpg: 384x640 2 fulls, 80.6ms
# Speed: 1.7ms preprocess, 80.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000084.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000085.jpg: 384x640 3 opens, 78.2ms
# Speed: 1.6ms preprocess, 78.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000085.jpg: 384x640 2 fulls, 100.2ms
# Speed: 1.2ms preprocess, 100.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000085.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000086.jpg: 384x640 2 opens, 88.6ms
# Speed: 2.7ms preprocess, 88.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000086.jpg: 384x640 3 fulls, 71.3ms
# Speed: 1.7ms preprocess, 71.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000086.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000087.jpg: 384x640 2 opens, 137.6ms
# Speed: 1.6ms preprocess, 137.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000087.jpg: 384x640 3 fulls, 66.0ms
# Speed: 2.2ms preprocess, 66.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000087.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000088.jpg: 384x640 2 opens, 62.4ms
# Speed: 1.5ms preprocess, 62.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000088.jpg: 384x640 3 fulls, 60.7ms
# Speed: 1.2ms preprocess, 60.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000088.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000089.jpg: 384x640 3 opens, 60.7ms
# Speed: 1.3ms preprocess, 60.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000089.jpg: 384x640 3 fulls, 60.1ms
# Speed: 1.2ms preprocess, 60.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000089.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000090.jpg: 384x640 3 opens, 62.3ms
# Speed: 1.3ms preprocess, 62.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000090.jpg: 384x640 3 fulls, 59.8ms
# Speed: 2.3ms preprocess, 59.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000090.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000091.jpg: 384x640 3 opens, 64.0ms
# Speed: 1.3ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000091.jpg: 384x640 3 fulls, 62.9ms
# Speed: 1.1ms preprocess, 62.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000091.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000092.jpg: 384x640 3 opens, 67.9ms
# Speed: 1.7ms preprocess, 67.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000092.jpg: 384x640 3 fulls, 64.7ms
# Speed: 1.2ms preprocess, 64.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000092.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000093.jpg: 384x640 3 opens, 77.6ms
# Speed: 1.5ms preprocess, 77.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000093.jpg: 384x640 3 fulls, 63.5ms
# Speed: 1.2ms preprocess, 63.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000093.jpg
#
# ...
# Speed: 1.2ms preprocess, 63.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000184.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000185.jpg: 384x640 (no detections), 76.7ms
# Speed: 1.2ms preprocess, 76.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000185.jpg: 384x640 1 full, 67.8ms
# Speed: 1.2ms preprocess, 67.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000185.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000186.jpg: 384x640 1 open, 84.5ms
# Speed: 2.6ms preprocess, 84.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000186.jpg: 384x640 1 full, 84.2ms
# Speed: 1.2ms preprocess, 84.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000186.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000187.jpg: 384x640 1 open, 66.1ms
# Speed: 1.4ms preprocess, 66.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000187.jpg: 384x640 1 full, 72.7ms
# Speed: 1.9ms preprocess, 72.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000187.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000188.jpg: 384x640 1 open, 67.9ms
# Speed: 2.0ms preprocess, 67.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000188.jpg: 384x640 1 full, 75.1ms
# Speed: 1.1ms preprocess, 75.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000188.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000189.jpg: 384x640 1 open, 83.3ms
# Speed: 2.8ms preprocess, 83.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000189.jpg: 384x640 1 full, 87.6ms
# Speed: 4.4ms preprocess, 87.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000189.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000190.jpg: 384x640 (no detections), 63.4ms
# Speed: 1.1ms preprocess, 63.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000190.jpg: 384x640 1 full, 117.2ms
# Speed: 1.1ms preprocess, 117.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000190.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000191.jpg: 384x640 1 open, 69.7ms
# Speed: 1.4ms preprocess, 69.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000191.jpg: 384x640 1 full, 65.9ms
# Speed: 1.2ms preprocess, 65.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000191.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000192.jpg: 384x640 1 open, 67.3ms
# Speed: 1.3ms preprocess, 67.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000192.jpg: 384x640 1 full, 83.2ms
# Speed: 1.1ms preprocess, 83.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000192.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000193.jpg: 384x640 (no detections), 67.2ms
# Speed: 1.2ms preprocess, 67.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000193.jpg: 384x640 (no detections), 59.1ms
# Speed: 1.1ms preprocess, 59.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000193.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000194.jpg: 384x640 (no detections), 67.3ms
# Speed: 1.3ms preprocess, 67.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000194.jpg: 384x640 1 full, 56.8ms
# Speed: 1.1ms preprocess, 56.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000194.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000195.jpg: 384x640 (no detections), 61.3ms
# Speed: 1.2ms preprocess, 61.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000195.jpg: 384x640 1 full, 62.0ms
# Speed: 1.2ms preprocess, 62.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000195.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000196.jpg: 384x640 (no detections), 67.1ms
# Speed: 1.2ms preprocess, 67.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000196.jpg: 384x640 (no detections), 69.2ms
# Speed: 1.3ms preprocess, 69.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000196.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000197.jpg: 384x640 (no detections), 72.7ms
# Speed: 1.4ms preprocess, 72.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000197.jpg: 384x640 (no detections), 63.3ms
# Speed: 1.1ms preprocess, 63.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000197.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000198.jpg: 384x640 (no detections), 89.8ms
# Speed: 1.4ms preprocess, 89.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000198.jpg: 384x640 (no detections), 84.7ms
# Speed: 1.4ms preprocess, 84.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000198.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000199.jpg: 384x640 (no detections), 66.0ms
# Speed: 1.2ms preprocess, 66.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000199.jpg: 384x640 1 full, 60.7ms
# Speed: 1.1ms preprocess, 60.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000199.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000200.jpg: 384x640 (no detections), 139.0ms
# Speed: 1.3ms preprocess, 139.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000200.jpg: 384x640 1 full, 84.3ms
# Speed: 1.7ms preprocess, 84.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000200.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000201.jpg: 384x640 (no detections), 97.6ms
# Speed: 3.0ms preprocess, 97.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000201.jpg: 384x640 1 full, 90.2ms
# Speed: 2.0ms preprocess, 90.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000201.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000202.jpg: 384x640 (no detections), 74.0ms
# Speed: 1.9ms preprocess, 74.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000202.jpg: 384x640 1 full, 61.7ms
# Speed: 1.3ms preprocess, 61.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000202.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000203.jpg: 384x640 (no detections), 116.8ms
# Speed: 1.2ms preprocess, 116.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000203.jpg: 384x640 1 full, 64.0ms
# Speed: 1.1ms preprocess, 64.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000203.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000204.jpg: 384x640 (no detections), 64.4ms
# Speed: 1.2ms preprocess, 64.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000204.jpg: 384x640 (no detections), 63.8ms
# Speed: 1.3ms preprocess, 63.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000204.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000205.jpg: 384x640 (no detections), 68.4ms
# Speed: 1.2ms preprocess, 68.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000205.jpg: 384x640 (no detections), 62.8ms
# Speed: 1.5ms preprocess, 62.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000205.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000206.jpg: 384x640 (no detections), 73.0ms
# Speed: 1.5ms preprocess, 73.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000206.jpg: 384x640 (no detections), 59.5ms
# Speed: 1.2ms preprocess, 59.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000206.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000207.jpg: 384x640 (no detections), 65.3ms
# Speed: 1.1ms preprocess, 65.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000207.jpg: 384x640 (no detections), 69.1ms
# Speed: 1.2ms preprocess, 69.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000207.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000208.jpg: 384x640 1 open, 63.7ms
# Speed: 1.2ms preprocess, 63.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000208.jpg: 384x640 1 full, 66.1ms
# Speed: 1.8ms preprocess, 66.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000208.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000209.jpg: 384x640 (no detections), 91.8ms
# Speed: 1.4ms preprocess, 91.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000209.jpg: 384x640 2 fulls, 63.8ms
# Speed: 1.9ms preprocess, 63.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000209.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000210.jpg: 384x640 (no detections), 123.0ms
# Speed: 1.1ms preprocess, 123.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000210.jpg: 384x640 (no detections), 63.5ms
# Speed: 1.1ms preprocess, 63.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000210.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000211.jpg: 384x640 (no detections), 64.2ms
# Speed: 1.4ms preprocess, 64.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000211.jpg: 384x640 (no detections), 61.4ms
# Speed: 1.1ms preprocess, 61.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000211.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000212.jpg: 384x640 (no detections), 70.1ms
# Speed: 3.9ms preprocess, 70.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000212.jpg: 384x640 1 full, 65.3ms
# Speed: 1.3ms preprocess, 65.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000212.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000213.jpg: 384x640 (no detections), 72.2ms
# Speed: 1.9ms preprocess, 72.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000213.jpg: 384x640 (no detections), 99.3ms
# Speed: 2.9ms preprocess, 99.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000213.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000214.jpg: 384x640 (no detections), 70.2ms
# Speed: 1.3ms preprocess, 70.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000214.jpg: 384x640 (no detections), 56.8ms
# Speed: 1.1ms preprocess, 56.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000214.jpg
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000215.jpg: 384x640 (no detections), 83.3ms
# Speed: 1.2ms preprocess, 83.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 g:\GitProjects\sessac_project\test_data\test_video\video_missing1_new_002\frame_000215.jpg: 384x640 (no detections), 73.6ms
# Speed: 1.4ms preprocess, 73.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# [INFO] Saved vis image: demo\yolo\frame_000215.jpg

# %%
# YOLO 시각화 이미지를 7.5fps 영상으로 변환
OUT_YOLO_VIDEO = r"video_normal_new_002.mp4"
OUT_OC_FE_DIR1 = r"demo\yolo\video_normal_new_002"
images_to_video(OUT_OC_FE_DIR1, OUT_YOLO_VIDEO, fps=7.5)

# YOLO 시각화 이미지를 7.5fps 영상으로 변환
OUT_YOLO_VIDEO = r"video_normal_new_003.mp4"
OUT_OC_FE_DIR2 = r"demo\yolo\video_normal_new_003"
images_to_video(OUT_OC_FE_DIR2, OUT_YOLO_VIDEO, fps=7.5)

# YOLO 시각화 이미지를 7.5fps 영상으로 변환
OUT_YOLO_VIDEO = r"video_missing1_new_002.mp4"
OUT_OC_FE_DIR3 = r"demo\yolo\video_missing1_new_002"
images_to_video(OUT_OC_FE_DIR3, OUT_YOLO_VIDEO, fps=7.5)
# Out:
# [INFO] Video saved: video_normal_new_002.mp4
# [INFO] Video saved: video_normal_new_003.mp4
# [INFO] Video saved: video_missing1_new_002.mp4

# %% [markdown]
# ## mediapipe 시각화

# %%
import mediapipe as mp

mp_hands = mp.solutions.hands
HAND_CONNECTIONS = mp_hands.HAND_CONNECTIONS  # (index1, index2) 쌍들의 set

# %%
FRAMES_DIR1      = r"test_data\test_video\video_normal_new_002(fast)"      # 원본 프레임 폴더
LANDMARK_NPZ1    = r"test_data\test_in_model\test_npz\hands_video_normal_new_002.npz"  # 미리 저장했던 npz

FRAMES_DIR2      = r"test_data\test_video\video_normal_new_003"      # 원본 프레임 폴더
LANDMARK_NPZ2    = r"test_data\test_in_model\test_npz\hands_video_normal_new_003.npz"  # 미리 저장했던 npz

FRAMES_DIR3      = r"test_data\test_video\video_missing1_new_002"      # 원본 프레임 폴더
LANDMARK_NPZ3    = r"test_data\test_in_model\test_npz\hands_video_missing1_new_002.npz"  # 미리 저장했던 npz

OUT_MP_DIR      = r"demo\media"             # 랜드마크 시각화 결과 저장 폴더
os.makedirs(OUT_MP_DIR, exist_ok=True)

# %%
# ===== 프레임 로딩 =====
frame_paths = []
for ext in ("*.jpg", "*.png"):
    frame_paths.extend(glob.glob(os.path.join(FRAMES_DIR1, ext)))
frame_paths = natsorted(frame_paths)

print(f"[INFO] Found {len(frame_paths)} frames")

# ===== npz 로딩 =====
data = np.load(LANDMARK_NPZ1)
flat = data["hand_kps"]              # (235, 126)
T, D = flat.shape
print("[INFO] hand_kps shape:", flat.shape)

# ===== reshape: (T, 42, 3) =====
assert D % 3 == 0, "차원이 3으로 나누어 떨어지지 않음!"
num_points = D // 3                  # 42
landmarks = flat.reshape(T, num_points, 3)
print("[INFO] reshaped:", landmarks.shape)

# ===== frame / landmark 길이 맞추기 =====
T2 = min(T, len(frame_paths))
print(f"[INFO] Using {T2} frames")

# ===== 왼손/오른손 분리 =====
NUM_HAND_POINTS = 21
LEFT_IDX  = slice(0, 21)             # 0~20
RIGHT_IDX = slice(21, 42)            # 21~41

# ===== 시각화 =====
for i in range(T2):
    img_path = frame_paths[i]
    img = cv2.imread(img_path)
    if img is None:
        continue
    
    h, w = img.shape[:2]
    lm = landmarks[i]                # (42, 3)

    # ----- 왼손 / 오른손 -----
    left  = lm[LEFT_IDX]             # (21, 3)
    right = lm[RIGHT_IDX]            # (21, 3)

    # ===== 포인트 그리기 함수 =====
    def draw_hand(points, color):
        # x,y 정규화 → 픽셀 변환
        xs = (points[:, 0] * w).astype(int)
        ys = (points[:, 1] * h).astype(int)

        # 점 그리기
        for x, y in zip(xs, ys):
            cv2.circle(img, (x, y), 3, color, -1)

        # 선 연결
        for c in HAND_CONNECTIONS:
            s, e = c
            x1, y1 = xs[s], ys[s]
            x2, y2 = xs[e], ys[e]
            cv2.line(img, (x1, y1), (x2, y2), color, 2)

    # ===== 실제 렌더링 =====

    FIXED_COLOR = (0, 255, 0)  # BGR, 연두색

    draw_hand(left,  FIXED_COLOR)
    draw_hand(right, FIXED_COLOR)
    
    # ===== 저장 =====
    out = os.path.join(OUT_MP_DIR, os.path.basename(img_path))
    cv2.imwrite(out, img)

print("[INFO] Mediapipe landmark visualization done.")
# Out:
# [INFO] Found 235 frames
# [INFO] hand_kps shape: (235, 126)
# [INFO] reshaped: (235, 42, 3)
# [INFO] Using 235 frames
# [INFO] Mediapipe landmark visualization done.

# %%
# ===== 프레임 로딩 =====
frame_paths = []
for ext in ("*.jpg", "*.png"):
    frame_paths.extend(glob.glob(os.path.join(FRAMES_DIR2, ext)))
frame_paths = natsorted(frame_paths)

print(f"[INFO] Found {len(frame_paths)} frames")

# ===== npz 로딩 =====
data = np.load(LANDMARK_NPZ2)
flat = data["hand_kps"]              # (235, 126)
T, D = flat.shape
print("[INFO] hand_kps shape:", flat.shape)

# ===== reshape: (T, 42, 3) =====
assert D % 3 == 0, "차원이 3으로 나누어 떨어지지 않음!"
num_points = D // 3                  # 42
landmarks = flat.reshape(T, num_points, 3)
print("[INFO] reshaped:", landmarks.shape)

# ===== frame / landmark 길이 맞추기 =====
T2 = min(T, len(frame_paths))
print(f"[INFO] Using {T2} frames")

# ===== 왼손/오른손 분리 =====
NUM_HAND_POINTS = 21
LEFT_IDX  = slice(0, 21)             # 0~20
RIGHT_IDX = slice(21, 42)            # 21~41

# ===== 시각화 =====
for i in range(T2):
    img_path = frame_paths[i]
    img = cv2.imread(img_path)
    if img is None:
        continue
    
    h, w = img.shape[:2]
    lm = landmarks[i]                # (42, 3)

    # ----- 왼손 / 오른손 -----
    left  = lm[LEFT_IDX]             # (21, 3)
    right = lm[RIGHT_IDX]            # (21, 3)

    # ===== 포인트 그리기 함수 =====
    def draw_hand(points, color):
        # x,y 정규화 → 픽셀 변환
        xs = (points[:, 0] * w).astype(int)
        ys = (points[:, 1] * h).astype(int)

        # 점 그리기
        for x, y in zip(xs, ys):
            cv2.circle(img, (x, y), 3, color, -1)

        # 선 연결
        for c in HAND_CONNECTIONS:
            s, e = c
            x1, y1 = xs[s], ys[s]
            x2, y2 = xs[e], ys[e]
            cv2.line(img, (x1, y1), (x2, y2), color, 2)

    # ===== 실제 렌더링 =====

    FIXED_COLOR = (0, 255, 0)  # BGR, 연두색

    draw_hand(left,  FIXED_COLOR)
    draw_hand(right, FIXED_COLOR)
    
    # ===== 저장 =====
    out = os.path.join(OUT_MP_DIR, os.path.basename(img_path))
    cv2.imwrite(out, img)

print("[INFO] Mediapipe landmark visualization done.")
# Out:
# [INFO] Found 452 frames
# [INFO] hand_kps shape: (452, 126)
# [INFO] reshaped: (452, 42, 3)
# [INFO] Using 452 frames
# [INFO] Mediapipe landmark visualization done.

# %%
# ===== 프레임 로딩 =====
frame_paths = []
for ext in ("*.jpg", "*.png"):
    frame_paths.extend(glob.glob(os.path.join(FRAMES_DIR3, ext)))
frame_paths = natsorted(frame_paths)

print(f"[INFO] Found {len(frame_paths)} frames")

# ===== npz 로딩 =====
data = np.load(LANDMARK_NPZ3)
flat = data["hand_kps"]              # (235, 126)
T, D = flat.shape
print("[INFO] hand_kps shape:", flat.shape)

# ===== reshape: (T, 42, 3) =====
assert D % 3 == 0, "차원이 3으로 나누어 떨어지지 않음!"
num_points = D // 3                  # 42
landmarks = flat.reshape(T, num_points, 3)
print("[INFO] reshaped:", landmarks.shape)

# ===== frame / landmark 길이 맞추기 =====
T2 = min(T, len(frame_paths))
print(f"[INFO] Using {T2} frames")

# ===== 왼손/오른손 분리 =====
NUM_HAND_POINTS = 21
LEFT_IDX  = slice(0, 21)             # 0~20
RIGHT_IDX = slice(21, 42)            # 21~41

# ===== 시각화 =====
for i in range(T2):
    img_path = frame_paths[i]
    img = cv2.imread(img_path)
    if img is None:
        continue
    
    h, w = img.shape[:2]
    lm = landmarks[i]                # (42, 3)

    # ----- 왼손 / 오른손 -----
    left  = lm[LEFT_IDX]             # (21, 3)
    right = lm[RIGHT_IDX]            # (21, 3)

    # ===== 포인트 그리기 함수 =====
    def draw_hand(points, color):
        # x,y 정규화 → 픽셀 변환
        xs = (points[:, 0] * w).astype(int)
        ys = (points[:, 1] * h).astype(int)

        # 점 그리기
        for x, y in zip(xs, ys):
            cv2.circle(img, (x, y), 3, color, -1)

        # 선 연결
        for c in HAND_CONNECTIONS:
            s, e = c
            x1, y1 = xs[s], ys[s]
            x2, y2 = xs[e], ys[e]
            cv2.line(img, (x1, y1), (x2, y2), color, 2)

    # ===== 실제 렌더링 =====

    FIXED_COLOR = (0, 255, 0)  # BGR, 연두색

    draw_hand(left,  FIXED_COLOR)
    draw_hand(right, FIXED_COLOR)
    
    # ===== 저장 =====
    out = os.path.join(OUT_MP_DIR, os.path.basename(img_path))
    cv2.imwrite(out, img)

print("[INFO] Mediapipe landmark visualization done.")
# Out:
# [INFO] Found 216 frames
# [INFO] hand_kps shape: (216, 126)
# [INFO] reshaped: (216, 42, 3)
# [INFO] Using 216 frames
# [INFO] Mediapipe landmark visualization done.

# %%
# YOLO 시각화 이미지를 7.5fps 영상으로 변환
OUT_MEDIA_VIDEO = r"demo\media\hands_video_normal_new_002.mp4"
OUT_OC_FE_DIR1 = r"demo\media\hands_video_normal_new_002"
images_to_video(OUT_OC_FE_DIR1, OUT_MEDIA_VIDEO, fps=7.5)

# YOLO 시각화 이미지를 7.5fps 영상으로 변환
OUT_MEDIA_VIDEO = r"demo\media\hands_video_normal_new_003.mp4"
OUT_OC_FE_DIR2 = r"demo\media\hands_video_normal_new_003"
images_to_video(OUT_OC_FE_DIR2, OUT_MEDIA_VIDEO, fps=7.5)

# YOLO 시각화 이미지를 7.5fps 영상으로 변환
OUT_MEDIA_VIDEO = r"demo\media\hands_video_missing1_new_002.mp4"
OUT_OC_FE_DIR3 = r"demo\media\hands_video_missing1_new_002"
images_to_video(OUT_OC_FE_DIR3, OUT_MEDIA_VIDEO, fps=7.5)
# Out:
# [INFO] Video saved: demo\media\hands_video_normal_new_002.mp4
# [INFO] Video saved: demo\media\hands_video_normal_new_003.mp4
# [INFO] Video saved: demo\media\hands_video_missing1_new_002.mp4
